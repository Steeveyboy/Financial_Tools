# %% [markdown]
# ### Requesting and Parsing API response
# <p style="max-width:40rem">This notebook will focus on using the datamodel to form a simplified income statement, balance sheet, and cashflows for a company using the api response.</p>

# %%
import requests
import pandas as pd
import sys
import json, helpful
pd.set_option('display.float_format', lambda x: '%0.2f' % x)

# %%
allTickers = json.loads(open("tickers.json", 'r').read())
ticker = "FB"
cik = allTickers[ticker]['cik']

# %%
user_agent = {"user-agent": "www.jonsteeves.dev jonathonsteeves@cmail.carleton.ca"}
url = "https://www.sec.gov/edgar/browse/?CIK=51143"
companyFacts = "https://data.sec.gov/api/xbrl/companyfacts/CIK{:010d}.json".format(cik)
api = "https://data.sec.gov/submissions/CIK0000051143.json"

# %%
res = requests.get(companyFacts, headers=user_agent)
res.status_code
# Out:
# 200

# %%
dc = dict(res.json())

# %%
dc['facts'].keys()
len(dc['facts']['us-gaap'])
# Out:
# 381

# %%
sys.getsizeof(dc["facts"]['us-gaap'])
# Out:
# 10292

# %%
# dc['facts']['dei']['EntityPublicFloat']

# %%
gaap = dc['facts']['us-gaap']

# %%
dataModel = json.loads(open('dataModels/dataModelV1.json', 'r').read())
gaapKeys = set(gaap.keys())

# %%
t = pd.DataFrame(helpful.keyQuarters(gaap["Revenues"]["units"]["USD"])[-10:])
t.fy = t.start.apply(lambda x: x.split("-")[0])

# %%
t
# Out:
#         start         end          val                  accn    fy  fp  form  \
# 0  2016-04-01  2016-06-30   6436000000  0001326801-17-000038  2016  Q2  10-Q
# 1  2016-07-01  2016-09-30   7011000000  0001326801-17-000053  2016  Q3  10-Q
# 2  2016-01-01  2016-12-31  27638000000  0001326801-18-000009  2016  FY  10-K
# 3  2017-01-01  2017-03-31   8032000000  0001326801-18-000032  2017  Q1  10-Q
# 4  2017-04-01  2017-06-30   9321000000  0001326801-18-000057  2017  Q2  10-Q
# 5  2017-07-01  2017-09-30  10328000000  0001326801-18-000067  2017  Q3  10-Q
# 6  2017-01-01  2017-12-31  40653000000  0001326801-18-000009  2017  FY  10-K
# 7  2018-01-01  2018-03-31  11966000000  0001326801-18-000032  2018  Q1  10-Q
# 8  2018-04-01  2018-06-30  13231000000  0001326801-18-000057  2018  Q2  10-Q
# 9  2018-07-01  2018-09-30  13727000000  0001326801-18-000067  2018  Q3  10-Q
#
#         filed     frame
# 0  2017-07-27  CY2016Q2
# 1  2017-11-02  CY2016Q3
# 2  2018-02-01    CY2016
# 3  2018-04-26  CY2017Q1
# 4  2018-07-26  CY2017Q2
# 5  2018-10-31  CY2017Q3
# 6  2018-02-01    CY2017
# 7  2018-04-26  CY2018Q1
# 8  2018-07-26  CY2018Q2
# 9  2018-10-31  CY2018Q3

# %%
def keyQuarters(ls):
    newls = []
    for frame in ls:
        if('frame' in frame.keys()):
            newls.append(frame)
    return newls

def make_frame(df):
    dataModel = json.loads(open('dataModels/dataModelV3_Income.json', 'r').read())
    incomeModel = dataModel["IncomeStatements"]
    df_model = pd.DataFrame()
    for i in incomeModel:
        try:
            df_model[i] = consolidate(keyQuarters(df[incomeModel[i]]["units"]["USD"]))
        except:
            print(df[incomeModel[i]]["units"]["USD"])
            df_model[i] = None
        # return pd.DataFrame(keyQuarters(df[dataModel[i]]["units"]["USD"]))
    
        # print(df[dataModel[i]]["units"]["USD"][-1])
        # return pd.DataFrame(df[dataModel[i]]["units"]["USD"])
    return df_model

def consolidate(ls):
    frame = pd.DataFrame(ls)
    frame.fy = frame.end.apply(lambda x: x.split("-")[0])
    # frame.fy = frame.end.apply(lambda x: x.split("-")[0])
    frame = frame[["fy", "val", "frame", "form"]]
    frame = pd.concat([frame, make_q4(frame)])
    # frame["date"] = frame["start"] + ', ' + frame["end"]
    
    frame["frame2"] = frame["frame"].transform(lambda x: x[2:])
    # frame = frame.set_index('frame')
    # frame.drop(["start", "end", "accn", "filed"], axis=1, inplace=True)
    return frame[frame["form"] != "10-K"].sort_values(["fy", "form"]).set_index("frame")["val"]

def make_q4(arr):
    crs = pd.crosstab(arr["fy"], arr["form"], values=arr["val"], aggfunc="sum")
    q = crs["10-K"] - crs["10-Q"]
    out = pd.DataFrame(q.dropna(), columns=["val"]).reset_index()
    out["frame"] = out["fy"].transform(lambda x: f"CY{x}Q4")
    out["form"] = "10-Q"
    return out

# %%
dataModel = json.loads(open('dataModel/dataModelV3_Income.json', 'r').read())
incomeModel = dataModel["IncomeStatements"]

# %%
dataModel
# Out:
# {'IncomeStatements': {'Total revenue': 'Revenues',
#   'Total cost': 'CostOfRevenue',
#   'Gross profit': 'GrossProfit',
#   'Selling, general and administrative': 'SellingGeneralAndAdministrativeExpense',
#   'Research, development and engineering': 'ResearchAndDevelopmentExpense',
#   'Interest expense': 'InterestExpense',
#   'Income before taxes': 'IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest',
#   'Net income': 'NetIncomeLoss'},
#  'BalanceSheet': {'Total current assets': 'AssetsCurrent',
#   'Total assets': 'Assets',
#   'Total current liabilities': 'LiabilitiesCurrent',
#   'Total liabilities': 'Liabilities',
#   'Retained earnings': 'RetainedEarningsAccumulatedDeficit',
#   'Total equity': 'StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest',
#   'Total liabilities and equity': 'LiabilitiesAndStockholdersEquity'}}

# %%
for i in incomeModel:
    print(incomeModel[i])
# Out:
# Revenues
# CostOfRevenue
# GrossProfit
# SellingGeneralAndAdministrativeExpense
# ResearchAndDevelopmentExpense
# InterestExpense
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest
# NetIncomeLoss

# %%
p = pd.DataFrame(gaap).drop("units")

# %%
p.T.reset_index()
# Out:
#                                                  index  \
# 0     AccountsPayableAndOtherAccruedLiabilitiesCurrent
# 1                               AccountsPayableCurrent
# 2                          AccountsPayableOtherCurrent
# 3                          AccountsPayableTradeCurrent
# 4                         AccountsReceivableNetCurrent
# ..                                                 ...
# 376               ContractualObligationDueInSecondYear
# 377                ContractualObligationDueInThirdYear
# 378  ContractualObligationFutureMinimumPaymentsDueR...
# 379                      GoodwillOtherIncreaseDecrease
# 380        ProceedsFromSaleOfPropertyPlantAndEquipment
#
#                                                  label  \
# 0    Accounts Payable and Other Accrued Liabilities...
# 1                            Accounts Payable, Current
# 2                     Accounts Payable, Other, Current
# 3                     Accounts Payable, Trade, Current
# 4    Accounts Receivable, after Allowance for Credi...
# ..                                                 ...
# 376       Contractual Obligation, to be Paid, Year Two
# 377     Contractual Obligation, to be Paid, Year Three
# 378  Contractual Obligation, to be Paid, Remainder ...
# 379                Goodwill, Other Increase (Decrease)
# 380  Proceeds from Sale of Property, Plant, and Equ...
#
#                                            description
# 0    Amount of liabilities incurred to vendors for ...
# 1    Carrying value as of the balance sheet date of...
# 2    Amount of obligations incurred classified as o...
# 3    Carrying value as of the balance sheet date of...
# 4    Amount, after allowance for credit loss, of ri...
# ..                                                 ...
# 376  Amount of contractual obligation to be paid in...
# 377  Amount of contractual obligation to be paid in...
# 378  Amount of contractual obligation to be paid in...
# 379  Amount of increase (decrease), classified as o...
# 380  The cash inflow from the sale of long-lived, p...
#
# [381 rows x 3 columns]

# %%
gaap["OperatingIncomeLoss"]
# Out:
# {'label': 'Operating Income (Loss)',
#  'description': 'The net result for the period of deducting operating expenses from operating revenues.',
#  'units': {'USD': [{'start': '2010-01-01',
#     'end': '2010-12-31',
#     'val': 1032000000,
#     'accn': '0001326801-13-000003',
#     'fy': 2012,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2013-02-01',
#     'frame': 'CY2010'},
#    {'start': '2011-01-01',
#     'end': '2011-06-30',
#     'val': 795000000,
#     'accn': '0001193125-12-325997',
#     'fy': 2012,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2012-07-31'},
#    {'start': '2011-04-01',
#     'end': '2011-06-30',
#     'val': 407000000,
#     'accn': '0001193125-12-325997',
#     'fy': 2012,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2012-07-31',
#     'frame': 'CY2011Q2'},
#    {'start': '2011-01-01',
#     'end': '2011-09-30',
#     'val': 1209000000,
#     'accn': '0001326801-12-000006',
#     'fy': 2012,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2012-10-24'},
#    {'start': '2011-07-01',
#     'end': '2011-09-30',
#     'val': 414000000,
#     'accn': '0001326801-12-000006',
#     'fy': 2012,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2012-10-24',
#     'frame': 'CY2011Q3'},
#    {'start': '2011-01-01',
#     'end': '2011-12-31',
#     'val': 1756000000,
#     'accn': '0001326801-13-000003',
#     'fy': 2012,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2013-02-01'},
#    {'start': '2011-01-01',
#     'end': '2011-12-31',
#     'val': 1756000000,
#     'accn': '0001326801-14-000007',
#     'fy': 2013,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2014-01-31',
#     'frame': 'CY2011'},
#    {'start': '2012-01-01',
#     'end': '2012-03-31',
#     'val': 381000000,
#     'accn': '0001326801-13-000011',
#     'fy': 2013,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2013-05-02',
#     'frame': 'CY2012Q1'},
#    {'start': '2012-01-01',
#     'end': '2012-06-30',
#     'val': -362000000,
#     'accn': '0001193125-12-325997',
#     'fy': 2012,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2012-07-31'},
#    {'start': '2012-01-01',
#     'end': '2012-06-30',
#     'val': -362000000,
#     'accn': '0001326801-13-000019',
#     'fy': 2013,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2013-07-25'},
#    {'start': '2012-04-01',
#     'end': '2012-06-30',
#     'val': -743000000,
#     'accn': '0001193125-12-325997',
#     'fy': 2012,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2012-07-31'},
#    {'start': '2012-04-01',
#     'end': '2012-06-30',
#     'val': -743000000,
#     'accn': '0001326801-13-000019',
#     'fy': 2013,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2013-07-25',
#     'frame': 'CY2012Q2'},
#    {'start': '2012-01-01',
#     'end': '2012-09-30',
#     'val': 15000000,
#     'accn': '0001326801-12-000006',
#     'fy': 2012,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2012-10-24'},
#    {'start': '2012-01-01',
#     'end': '2012-09-30',
#     'val': 15000000,
#     'accn': '0001326801-13-000031',
#     'fy': 2013,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2013-11-01'},
#    {'start': '2012-07-01',
#     'end': '2012-09-30',
#     'val': 377000000,
#     'accn': '0001326801-12-000006',
#     'fy': 2012,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2012-10-24'},
#    {'start': '2012-07-01',
#     'end': '2012-09-30',
#     'val': 377000000,
#     'accn': '0001326801-13-000031',
#     'fy': 2013,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2013-11-01',
#     'frame': 'CY2012Q3'},
#    {'start': '2012-01-01',
#     'end': '2012-12-31',
#     'val': 538000000,
#     'accn': '0001326801-13-000003',
#     'fy': 2012,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2013-02-01'},
#    {'start': '2012-01-01',
#     'end': '2012-12-31',
#     'val': 538000000,
#     'accn': '0001326801-14-000007',
#     'fy': 2013,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2014-01-31'},
#    {'start': '2012-01-01',
#     'end': '2012-12-31',
#     'val': 538000000,
#     'accn': '0001326801-15-000006',
#     'fy': 2014,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2015-01-29',
#     'frame': 'CY2012'},
#    {'start': '2013-01-01',
#     'end': '2013-03-31',
#     'val': 373000000,
#     'accn': '0001326801-13-000011',
#     'fy': 2013,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2013-05-02'},
#    {'start': '2013-01-01',
#     'end': '2013-03-31',
#     'val': 373000000,
#     'accn': '0001326801-14-000023',
#     'fy': 2014,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2014-04-25',
#     'frame': 'CY2013Q1'},
#    {'start': '2013-01-01',
#     'end': '2013-06-30',
#     'val': 935000000,
#     'accn': '0001326801-13-000019',
#     'fy': 2013,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2013-07-25'},
#    {'start': '2013-01-01',
#     'end': '2013-06-30',
#     'val': 935000000,
#     'accn': '0001326801-14-000032',
#     'fy': 2014,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2014-07-24'},
#    {'start': '2013-04-01',
#     'end': '2013-06-30',
#     'val': 562000000,
#     'accn': '0001326801-13-000019',
#     'fy': 2013,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2013-07-25'},
#    {'start': '2013-04-01',
#     'end': '2013-06-30',
#     'val': 562000000,
#     'accn': '0001326801-14-000032',
#     'fy': 2014,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2014-07-24',
#     'frame': 'CY2013Q2'},
#    {'start': '2013-01-01',
#     'end': '2013-09-30',
#     'val': 1672000000,
#     'accn': '0001326801-13-000031',
#     'fy': 2013,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2013-11-01'},
#    {'start': '2013-01-01',
#     'end': '2013-09-30',
#     'val': 1672000000,
#     'accn': '0001326801-14-000068',
#     'fy': 2014,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2014-10-30'},
#    {'start': '2013-07-01',
#     'end': '2013-09-30',
#     'val': 736000000,
#     'accn': '0001326801-13-000031',
#     'fy': 2013,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2013-11-01'},
#    {'start': '2013-07-01',
#     'end': '2013-09-30',
#     'val': 736000000,
#     'accn': '0001326801-14-000068',
#     'fy': 2014,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2014-10-30',
#     'frame': 'CY2013Q3'},
#    {'start': '2013-01-01',
#     'end': '2013-12-31',
#     'val': 2804000000,
#     'accn': '0001326801-14-000007',
#     'fy': 2013,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2014-01-31'},
#    {'start': '2013-01-01',
#     'end': '2013-12-31',
#     'val': 2804000000,
#     'accn': '0001326801-15-000006',
#     'fy': 2014,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2015-01-29'},
#    {'start': '2013-01-01',
#     'end': '2013-12-31',
#     'val': 2804000000,
#     'accn': '0001326801-16-000043',
#     'fy': 2015,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2016-01-28',
#     'frame': 'CY2013'},
#    {'start': '2014-01-01',
#     'end': '2014-03-31',
#     'val': 1075000000,
#     'accn': '0001326801-14-000023',
#     'fy': 2014,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2014-04-25'},
#    {'start': '2014-01-01',
#     'end': '2014-03-31',
#     'val': 1075000000,
#     'accn': '0001326801-15-000015',
#     'fy': 2015,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2015-04-23',
#     'frame': 'CY2014Q1'},
#    {'start': '2014-01-01',
#     'end': '2014-06-30',
#     'val': 2464000000,
#     'accn': '0001326801-14-000032',
#     'fy': 2014,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2014-07-24'},
#    {'start': '2014-01-01',
#     'end': '2014-06-30',
#     'val': 2464000000,
#     'accn': '0001326801-15-000028',
#     'fy': 2015,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2015-07-31'},
#    {'start': '2014-04-01',
#     'end': '2014-06-30',
#     'val': 1390000000,
#     'accn': '0001326801-14-000032',
#     'fy': 2014,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2014-07-24'},
#    {'start': '2014-04-01',
#     'end': '2014-06-30',
#     'val': 1390000000,
#     'accn': '0001326801-15-000028',
#     'fy': 2015,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2015-07-31',
#     'frame': 'CY2014Q2'},
#    {'start': '2014-01-01',
#     'end': '2014-09-30',
#     'val': 3861000000,
#     'accn': '0001326801-14-000068',
#     'fy': 2014,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2014-10-30'},
#    {'start': '2014-01-01',
#     'end': '2014-09-30',
#     'val': 3861000000,
#     'accn': '0001326801-15-000032',
#     'fy': 2015,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2015-11-05'},
#    {'start': '2014-07-01',
#     'end': '2014-09-30',
#     'val': 1397000000,
#     'accn': '0001326801-14-000068',
#     'fy': 2014,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2014-10-30'},
#    {'start': '2014-07-01',
#     'end': '2014-09-30',
#     'val': 1397000000,
#     'accn': '0001326801-15-000032',
#     'fy': 2015,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2015-11-05',
#     'frame': 'CY2014Q3'},
#    {'start': '2014-01-01',
#     'end': '2014-12-31',
#     'val': 4994000000,
#     'accn': '0001326801-15-000006',
#     'fy': 2014,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2015-01-29'},
#    {'start': '2014-01-01',
#     'end': '2014-12-31',
#     'val': 4994000000,
#     'accn': '0001326801-16-000043',
#     'fy': 2015,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2016-01-28'},
#    {'start': '2014-01-01',
#     'end': '2014-12-31',
#     'val': 4994000000,
#     'accn': '0001326801-17-000007',
#     'fy': 2016,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2017-02-03',
#     'frame': 'CY2014'},
#    {'start': '2015-01-01',
#     'end': '2015-03-31',
#     'val': 933000000,
#     'accn': '0001326801-15-000015',
#     'fy': 2015,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2015-04-23'},
#    {'start': '2015-01-01',
#     'end': '2015-03-31',
#     'val': 933000000,
#     'accn': '0001326801-16-000067',
#     'fy': 2016,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2016-04-28',
#     'frame': 'CY2015Q1'},
#    {'start': '2015-01-01',
#     'end': '2015-06-30',
#     'val': 2206000000,
#     'accn': '0001326801-15-000028',
#     'fy': 2015,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2015-07-31'},
#    {'start': '2015-01-01',
#     'end': '2015-06-30',
#     'val': 2206000000,
#     'accn': '0001326801-16-000082',
#     'fy': 2016,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2016-07-28'},
#    {'start': '2015-04-01',
#     'end': '2015-06-30',
#     'val': 1273000000,
#     'accn': '0001326801-15-000028',
#     'fy': 2015,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2015-07-31'},
#    {'start': '2015-04-01',
#     'end': '2015-06-30',
#     'val': 1273000000,
#     'accn': '0001326801-16-000082',
#     'fy': 2016,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2016-07-28',
#     'frame': 'CY2015Q2'},
#    {'start': '2015-01-01',
#     'end': '2015-09-30',
#     'val': 3665000000,
#     'accn': '0001326801-15-000032',
#     'fy': 2015,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2015-11-05'},
#    {'start': '2015-01-01',
#     'end': '2015-09-30',
#     'val': 3665000000,
#     'accn': '0001326801-16-000087',
#     'fy': 2016,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2016-11-03'},
#    {'start': '2015-07-01',
#     'end': '2015-09-30',
#     'val': 1459000000,
#     'accn': '0001326801-15-000032',
#     'fy': 2015,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2015-11-05'},
#    {'start': '2015-07-01',
#     'end': '2015-09-30',
#     'val': 1459000000,
#     'accn': '0001326801-16-000087',
#     'fy': 2016,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2016-11-03',
#     'frame': 'CY2015Q3'},
#    {'start': '2015-01-01',
#     'end': '2015-12-31',
#     'val': 6225000000,
#     'accn': '0001326801-16-000043',
#     'fy': 2015,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2016-01-28'},
#    {'start': '2015-01-01',
#     'end': '2015-12-31',
#     'val': 6225000000,
#     'accn': '0001326801-17-000007',
#     'fy': 2016,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2017-02-03'},
#    {'start': '2015-01-01',
#     'end': '2015-12-31',
#     'val': 6225000000,
#     'accn': '0001326801-18-000009',
#     'fy': 2017,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2018-02-01',
#     'frame': 'CY2015'},
#    {'start': '2016-01-01',
#     'end': '2016-03-31',
#     'val': 2009000000,
#     'accn': '0001326801-16-000067',
#     'fy': 2016,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2016-04-28'},
#    {'start': '2016-01-01',
#     'end': '2016-03-31',
#     'val': 2010000000,
#     'accn': '0001326801-17-000024',
#     'fy': 2017,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2017-05-04',
#     'frame': 'CY2016Q1'},
#    {'start': '2016-01-01',
#     'end': '2016-06-30',
#     'val': 4754000000,
#     'accn': '0001326801-16-000082',
#     'fy': 2016,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2016-07-28'},
#    {'start': '2016-01-01',
#     'end': '2016-06-30',
#     'val': 4743000000,
#     'accn': '0001326801-17-000038',
#     'fy': 2017,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2017-07-27'},
#    {'start': '2016-04-01',
#     'end': '2016-06-30',
#     'val': 2746000000,
#     'accn': '0001326801-16-000082',
#     'fy': 2016,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2016-07-28'},
#    {'start': '2016-04-01',
#     'end': '2016-06-30',
#     'val': 2734000000,
#     'accn': '0001326801-17-000038',
#     'fy': 2017,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2017-07-27',
#     'frame': 'CY2016Q2'},
#    {'start': '2016-01-01',
#     'end': '2016-09-30',
#     'val': 7876000000,
#     'accn': '0001326801-16-000087',
#     'fy': 2016,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2016-11-03'},
#    {'start': '2016-01-01',
#     'end': '2016-09-30',
#     'val': 7860000000,
#     'accn': '0001326801-17-000053',
#     'fy': 2017,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2017-11-02'},
#    {'start': '2016-07-01',
#     'end': '2016-09-30',
#     'val': 3122000000,
#     'accn': '0001326801-16-000087',
#     'fy': 2016,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2016-11-03'},
#    {'start': '2016-07-01',
#     'end': '2016-09-30',
#     'val': 3117000000,
#     'accn': '0001326801-17-000053',
#     'fy': 2017,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2017-11-02',
#     'frame': 'CY2016Q3'},
#    {'start': '2016-01-01',
#     'end': '2016-12-31',
#     'val': 12427000000,
#     'accn': '0001326801-17-000007',
#     'fy': 2016,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2017-02-03'},
#    {'start': '2016-01-01',
#     'end': '2016-12-31',
#     'val': 12427000000,
#     'accn': '0001326801-18-000009',
#     'fy': 2017,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2018-02-01'},
#    {'start': '2016-01-01',
#     'end': '2016-12-31',
#     'val': 12427000000,
#     'accn': '0001326801-19-000009',
#     'fy': 2018,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2019-01-31',
#     'frame': 'CY2016'},
#    {'start': '2017-01-01',
#     'end': '2017-03-31',
#     'val': 3327000000,
#     'accn': '0001326801-17-000024',
#     'fy': 2017,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2017-05-04'},
#    {'start': '2017-01-01',
#     'end': '2017-03-31',
#     'val': 3327000000,
#     'accn': '0001326801-18-000032',
#     'fy': 2018,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2018-04-26',
#     'frame': 'CY2017Q1'},
#    {'start': '2017-01-01',
#     'end': '2017-06-30',
#     'val': 7729000000,
#     'accn': '0001326801-17-000038',
#     'fy': 2017,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2017-07-27'},
#    {'start': '2017-01-01',
#     'end': '2017-06-30',
#     'val': 7729000000,
#     'accn': '0001326801-18-000057',
#     'fy': 2018,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2018-07-26'},
#    {'start': '2017-04-01',
#     'end': '2017-06-30',
#     'val': 4401000000,
#     'accn': '0001326801-17-000038',
#     'fy': 2017,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2017-07-27'},
#    {'start': '2017-04-01',
#     'end': '2017-06-30',
#     'val': 4401000000,
#     'accn': '0001326801-18-000057',
#     'fy': 2018,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2018-07-26',
#     'frame': 'CY2017Q2'},
#    {'start': '2017-01-01',
#     'end': '2017-09-30',
#     'val': 12851000000,
#     'accn': '0001326801-17-000053',
#     'fy': 2017,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2017-11-02'},
#    {'start': '2017-01-01',
#     'end': '2017-09-30',
#     'val': 12851000000,
#     'accn': '0001326801-18-000067',
#     'fy': 2018,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2018-10-31'},
#    {'start': '2017-07-01',
#     'end': '2017-09-30',
#     'val': 5122000000,
#     'accn': '0001326801-17-000053',
#     'fy': 2017,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2017-11-02'},
#    {'start': '2017-07-01',
#     'end': '2017-09-30',
#     'val': 5122000000,
#     'accn': '0001326801-18-000067',
#     'fy': 2018,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2018-10-31',
#     'frame': 'CY2017Q3'},
#    {'start': '2017-01-01',
#     'end': '2017-12-31',
#     'val': 20203000000,
#     'accn': '0001326801-18-000009',
#     'fy': 2017,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2018-02-01'},
#    {'start': '2017-01-01',
#     'end': '2017-12-31',
#     'val': 20203000000,
#     'accn': '0001326801-19-000009',
#     'fy': 2018,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2019-01-31'},
#    {'start': '2017-01-01',
#     'end': '2017-12-31',
#     'val': 20203000000,
#     'accn': '0001326801-20-000013',
#     'fy': 2019,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2020-01-30',
#     'frame': 'CY2017'},
#    {'start': '2018-01-01',
#     'end': '2018-03-31',
#     'val': 5449000000,
#     'accn': '0001326801-18-000032',
#     'fy': 2018,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2018-04-26'},
#    {'start': '2018-01-01',
#     'end': '2018-03-31',
#     'val': 5449000000,
#     'accn': '0001326801-19-000037',
#     'fy': 2019,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2019-04-25',
#     'frame': 'CY2018Q1'},
#    {'start': '2018-01-01',
#     'end': '2018-06-30',
#     'val': 11313000000,
#     'accn': '0001326801-18-000057',
#     'fy': 2018,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2018-07-26'},
#    {'start': '2018-01-01',
#     'end': '2018-06-30',
#     'val': 11313000000,
#     'accn': '0001326801-19-000055',
#     'fy': 2019,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2019-07-25'},
#    {'start': '2018-04-01',
#     'end': '2018-06-30',
#     'val': 5863000000,
#     'accn': '0001326801-18-000057',
#     'fy': 2018,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2018-07-26'},
#    {'start': '2018-04-01',
#     'end': '2018-06-30',
#     'val': 5863000000,
#     'accn': '0001326801-19-000055',
#     'fy': 2019,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2019-07-25',
#     'frame': 'CY2018Q2'},
#    {'start': '2018-01-01',
#     'end': '2018-09-30',
#     'val': 17093000000,
#     'accn': '0001326801-18-000067',
#     'fy': 2018,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2018-10-31'},
#    {'start': '2018-01-01',
#     'end': '2018-09-30',
#     'val': 17093000000,
#     'accn': '0001326801-19-000069',
#     'fy': 2019,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2019-10-31'},
#    {'start': '2018-07-01',
#     'end': '2018-09-30',
#     'val': 5781000000,
#     'accn': '0001326801-18-000067',
#     'fy': 2018,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2018-10-31'},
#    {'start': '2018-07-01',
#     'end': '2018-09-30',
#     'val': 5781000000,
#     'accn': '0001326801-19-000069',
#     'fy': 2019,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2019-10-31',
#     'frame': 'CY2018Q3'},
#    {'start': '2018-01-01',
#     'end': '2018-12-31',
#     'val': 24913000000,
#     'accn': '0001326801-19-000009',
#     'fy': 2018,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2019-01-31'},
#    {'start': '2018-01-01',
#     'end': '2018-12-31',
#     'val': 24913000000,
#     'accn': '0001326801-20-000013',
#     'fy': 2019,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2020-01-30'},
#    {'start': '2018-01-01',
#     'end': '2018-12-31',
#     'val': 24913000000,
#     'accn': '0001326801-21-000014',
#     'fy': 2020,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2021-01-28',
#     'frame': 'CY2018'},
#    {'start': '2019-01-01',
#     'end': '2019-03-31',
#     'val': 3317000000,
#     'accn': '0001326801-19-000037',
#     'fy': 2019,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2019-04-25'},
#    {'start': '2019-01-01',
#     'end': '2019-03-31',
#     'val': 3317000000,
#     'accn': '0001326801-20-000048',
#     'fy': 2020,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2020-04-30',
#     'frame': 'CY2019Q1'},
#    {'start': '2019-01-01',
#     'end': '2019-06-30',
#     'val': 7943000000,
#     'accn': '0001326801-19-000055',
#     'fy': 2019,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2019-07-25'},
#    {'start': '2019-01-01',
#     'end': '2019-06-30',
#     'val': 7943000000,
#     'accn': '0001326801-20-000076',
#     'fy': 2020,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2020-07-31'},
#    {'start': '2019-04-01',
#     'end': '2019-06-30',
#     'val': 4626000000,
#     'accn': '0001326801-19-000055',
#     'fy': 2019,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2019-07-25'},
#    {'start': '2019-04-01',
#     'end': '2019-06-30',
#     'val': 4626000000,
#     'accn': '0001326801-20-000076',
#     'fy': 2020,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2020-07-31',
#     'frame': 'CY2019Q2'},
#    {'start': '2019-01-01',
#     'end': '2019-09-30',
#     'val': 15128000000,
#     'accn': '0001326801-19-000069',
#     'fy': 2019,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2019-10-31'},
#    {'start': '2019-01-01',
#     'end': '2019-09-30',
#     'val': 15128000000,
#     'accn': '0001326801-20-000084',
#     'fy': 2020,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2020-10-30'},
#    {'start': '2019-07-01',
#     'end': '2019-09-30',
#     'val': 7185000000,
#     'accn': '0001326801-19-000069',
#     'fy': 2019,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2019-10-31'},
#    {'start': '2019-07-01',
#     'end': '2019-09-30',
#     'val': 7185000000,
#     'accn': '0001326801-20-000084',
#     'fy': 2020,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2020-10-30',
#     'frame': 'CY2019Q3'},
#    {'start': '2019-01-01',
#     'end': '2019-12-31',
#     'val': 23986000000,
#     'accn': '0001326801-20-000013',
#     'fy': 2019,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2020-01-30'},
#    {'start': '2019-01-01',
#     'end': '2019-12-31',
#     'val': 23986000000,
#     'accn': '0001326801-21-000014',
#     'fy': 2020,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2021-01-28'},
#    {'start': '2019-01-01',
#     'end': '2019-12-31',
#     'val': 23986000000,
#     'accn': '0001326801-22-000018',
#     'fy': 2021,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2022-02-03',
#     'frame': 'CY2019'},
#    {'start': '2020-01-01',
#     'end': '2020-03-31',
#     'val': 5893000000,
#     'accn': '0001326801-20-000048',
#     'fy': 2020,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2020-04-30'},
#    {'start': '2020-01-01',
#     'end': '2020-03-31',
#     'val': 5893000000,
#     'accn': '0001326801-21-000033',
#     'fy': 2021,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2021-04-29',
#     'frame': 'CY2020Q1'},
#    {'start': '2020-01-01',
#     'end': '2020-06-30',
#     'val': 11856000000,
#     'accn': '0001326801-20-000076',
#     'fy': 2020,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2020-07-31'},
#    {'start': '2020-01-01',
#     'end': '2020-06-30',
#     'val': 11856000000,
#     'accn': '0001326801-21-000049',
#     'fy': 2021,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2021-07-29'},
#    {'start': '2020-04-01',
#     'end': '2020-06-30',
#     'val': 5963000000,
#     'accn': '0001326801-20-000076',
#     'fy': 2020,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2020-07-31'},
#    {'start': '2020-04-01',
#     'end': '2020-06-30',
#     'val': 5963000000,
#     'accn': '0001326801-21-000049',
#     'fy': 2021,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2021-07-29',
#     'frame': 'CY2020Q2'},
#    {'start': '2020-01-01',
#     'end': '2020-09-30',
#     'val': 19896000000,
#     'accn': '0001326801-20-000084',
#     'fy': 2020,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2020-10-30'},
#    {'start': '2020-01-01',
#     'end': '2020-09-30',
#     'val': 19896000000,
#     'accn': '0001326801-21-000065',
#     'fy': 2021,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2021-10-26'},
#    {'start': '2020-07-01',
#     'end': '2020-09-30',
#     'val': 8040000000,
#     'accn': '0001326801-20-000084',
#     'fy': 2020,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2020-10-30'},
#    {'start': '2020-07-01',
#     'end': '2020-09-30',
#     'val': 8040000000,
#     'accn': '0001326801-21-000065',
#     'fy': 2021,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2021-10-26',
#     'frame': 'CY2020Q3'},
#    {'start': '2020-01-01',
#     'end': '2020-12-31',
#     'val': 32671000000,
#     'accn': '0001326801-21-000014',
#     'fy': 2020,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2021-01-28'},
#    {'start': '2020-01-01',
#     'end': '2020-12-31',
#     'val': 32671000000,
#     'accn': '0001326801-22-000018',
#     'fy': 2021,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2022-02-03',
#     'frame': 'CY2020'},
#    {'start': '2021-01-01',
#     'end': '2021-03-31',
#     'val': 11378000000,
#     'accn': '0001326801-21-000033',
#     'fy': 2021,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2021-04-29'},
#    {'start': '2021-01-01',
#     'end': '2021-03-31',
#     'val': 11378000000,
#     'accn': '0001326801-22-000057',
#     'fy': 2022,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2022-04-28',
#     'frame': 'CY2021Q1'},
#    {'start': '2021-01-01',
#     'end': '2021-06-30',
#     'val': 23745000000,
#     'accn': '0001326801-21-000049',
#     'fy': 2021,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2021-07-29'},
#    {'start': '2021-04-01',
#     'end': '2021-06-30',
#     'val': 12367000000,
#     'accn': '0001326801-21-000049',
#     'fy': 2021,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2021-07-29',
#     'frame': 'CY2021Q2'},
#    {'start': '2021-01-01',
#     'end': '2021-09-30',
#     'val': 34168000000,
#     'accn': '0001326801-21-000065',
#     'fy': 2021,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2021-10-26'},
#    {'start': '2021-07-01',
#     'end': '2021-09-30',
#     'val': 10423000000,
#     'accn': '0001326801-21-000065',
#     'fy': 2021,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2021-10-26',
#     'frame': 'CY2021Q3'},
#    {'start': '2021-01-01',
#     'end': '2021-12-31',
#     'val': 46753000000,
#     'accn': '0001326801-22-000018',
#     'fy': 2021,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2022-02-03',
#     'frame': 'CY2021'},
#    {'start': '2022-01-01',
#     'end': '2022-03-31',
#     'val': 8524000000,
#     'accn': '0001326801-22-000057',
#     'fy': 2022,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2022-04-28',
#     'frame': 'CY2022Q1'}]}}

# %%
cht = make_frame(gaap)
# cht.T.to_excel("example_table2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [161], in make_frame(df)
#      13 try:
# ---> 14     df_model[i] = consolidate(keyQuarters(df[incomeModel[i]]["units"]["USD"]))
#      15 except:
#
# KeyError: 'GrossProfit'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Input In [173], in <cell line: 1>()
# ----> 1 cht = make_frame(gaap)
#
# Input In [161], in make_frame(df)
#      14     df_model[i] = consolidate(keyQuarters(df[incomeModel[i]]["units"]["USD"]))
#      15 except:
# ---> 16     print(df[incomeModel[i]]["units"]["USD"])
#      17     df_model[i] = None
#      18 # return pd.DataFrame(keyQuarters(df[dataModel[i]]["units"]["USD"]))
#      19
#      20 # print(df[dataModel[i]]["units"]["USD"][-1])
#      21 # return pd.DataFrame(df[dataModel[i]]["units"]["USD"])
#
# KeyError: 'GrossProfit'

# %%
cht.tail()
# Out:
#           Total revenue    Total cost  Gross profit  \
# frame
# CY2021Q1 13187000000.00 6160000000.00 7027000000.00
# CY2021Q2 18745000000.00 9741000000.00 9004000000.00
# CY2021Q3 17618000000.00 9447000000.00 8171000000.00
# CY2021Q4  7800000000.00  517000000.00 7284000000.00
# CY2022Q1 14197000000.00 6862000000.00 7335000000.00
#
#           Selling, general and administrative  \
# frame
# CY2021Q1                        4688000000.00
# CY2021Q2                        5334000000.00
# CY2021Q3                        4860000000.00
# CY2021Q4                        3863000000.00
# CY2022Q1                        4597000000.00
#
#           Research, development and engineering  Interest expense  \
# frame
# CY2021Q1                          1616000000.00      280000000.00
# CY2021Q2                          1657000000.00      281000000.00
# CY2021Q3                          1621000000.00      291000000.00
# CY2021Q4                          1594000000.00      303000000.00
# CY2022Q1                          1679000000.00      311000000.00
#
#           Income before taxes    Net income
# frame
# CY2021Q1         244000000.00  955000000.00
# CY2021Q2        1552000000.00 1325000000.00
# CY2021Q3        1319000000.00 1130000000.00
# CY2021Q4        1722000000.00 2333000000.00
# CY2022Q1         623000000.00  733000000.00

# %%
gaap["Revenues"]["units"]["USD"]
# Out:
# [{'start': '2007-01-01',
#   'end': '2007-12-31',
#   'val': 98786000000,
#   'accn': '0001047469-10-001151',
#   'fy': 2009,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2010-02-23',
#   'frame': 'CY2007'},
#  {'start': '2008-01-01',
#   'end': '2008-06-30',
#   'val': 51322000000,
#   'accn': '0001104659-09-045198',
#   'fy': 2009,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2009-07-28'},
#  {'start': '2008-04-01',
#   'end': '2008-06-30',
#   'val': 26820000000,
#   'accn': '0001104659-09-045198',
#   'fy': 2009,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2009-07-28',
#   'frame': 'CY2008Q2'},
#  {'start': '2008-01-01',
#   'end': '2008-09-30',
#   'val': 76623000000,
#   'accn': '0001104659-09-060554',
#   'fy': 2009,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2009-10-27'},
#  {'start': '2008-07-01',
#   'end': '2008-09-30',
#   'val': 25302000000,
#   'accn': '0001104659-09-060554',
#   'fy': 2009,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2009-10-27',
#   'frame': 'CY2008Q3'},
#  {'start': '2008-01-01',
#   'end': '2008-12-31',
#   'val': 103630000000,
#   'accn': '0001047469-10-001151',
#   'fy': 2009,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2010-02-23'},
#  {'start': '2008-01-01',
#   'end': '2008-12-31',
#   'val': 103630000000,
#   'accn': '0001047469-11-001117',
#   'fy': 2010,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2011-02-22',
#   'frame': 'CY2008'},
#  {'start': '2009-01-01',
#   'end': '2009-03-31',
#   'val': 21711000000,
#   'accn': '0001104659-10-022064',
#   'fy': 2010,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2010-04-27',
#   'frame': 'CY2009Q1'},
#  {'start': '2009-01-01',
#   'end': '2009-06-30',
#   'val': 44962000000,
#   'accn': '0001104659-09-045198',
#   'fy': 2009,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2009-07-28'},
#  {'start': '2009-01-01',
#   'end': '2009-06-30',
#   'val': 44962000000,
#   'accn': '0001104659-10-039808',
#   'fy': 2010,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2010-07-27'},
#  {'start': '2009-04-01',
#   'end': '2009-06-30',
#   'val': 23250000000,
#   'accn': '0001104659-09-045198',
#   'fy': 2009,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2009-07-28'},
#  {'start': '2009-04-01',
#   'end': '2009-06-30',
#   'val': 23250000000,
#   'accn': '0001104659-10-039808',
#   'fy': 2010,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2010-07-27',
#   'frame': 'CY2009Q2'},
#  {'start': '2009-01-01',
#   'end': '2009-09-30',
#   'val': 68528000000,
#   'accn': '0001104659-09-060554',
#   'fy': 2009,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2009-10-27'},
#  {'start': '2009-01-01',
#   'end': '2009-09-30',
#   'val': 68528000000,
#   'accn': '0001104659-10-053716',
#   'fy': 2010,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2010-10-26'},
#  {'start': '2009-07-01',
#   'end': '2009-09-30',
#   'val': 23566000000,
#   'accn': '0001104659-09-060554',
#   'fy': 2009,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2009-10-27'},
#  {'start': '2009-07-01',
#   'end': '2009-09-30',
#   'val': 23566000000,
#   'accn': '0001104659-10-053716',
#   'fy': 2010,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2010-10-26',
#   'frame': 'CY2009Q3'},
#  {'start': '2008-12-31',
#   'end': '2009-12-31',
#   'val': 95758000000,
#   'accn': '0001047469-11-001117',
#   'fy': 2010,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2011-02-22'},
#  {'start': '2008-12-31',
#   'end': '2009-12-31',
#   'val': 95758000000,
#   'accn': '0001047469-12-001742',
#   'fy': 2011,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2012-02-28',
#   'frame': 'CY2009'},
#  {'start': '2009-01-01',
#   'end': '2009-12-31',
#   'val': 95758000000,
#   'accn': '0001047469-10-001151',
#   'fy': 2009,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2010-02-23'},
#  {'start': '2010-01-01',
#   'end': '2010-03-31',
#   'val': 22857000000,
#   'accn': '0001104659-10-022064',
#   'fy': 2010,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2010-04-27'},
#  {'start': '2010-01-01',
#   'end': '2010-03-31',
#   'val': 22857000000,
#   'accn': '0001104659-11-022352',
#   'fy': 2011,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2011-04-26',
#   'frame': 'CY2010Q1'},
#  {'start': '2010-01-01',
#   'end': '2010-06-30',
#   'val': 46581000000,
#   'accn': '0001104659-10-039808',
#   'fy': 2010,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2010-07-27'},
#  {'start': '2010-01-01',
#   'end': '2010-06-30',
#   'val': 46581000000,
#   'accn': '0001104659-11-040759',
#   'fy': 2011,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2011-07-26'},
#  {'start': '2010-04-01',
#   'end': '2010-06-30',
#   'val': 23724000000,
#   'accn': '0001104659-10-039808',
#   'fy': 2010,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2010-07-27'},
#  {'start': '2010-04-01',
#   'end': '2010-06-30',
#   'val': 23724000000,
#   'accn': '0001104659-11-040759',
#   'fy': 2011,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2011-07-26',
#   'frame': 'CY2010Q2'},
#  {'start': '2010-01-01',
#   'end': '2010-09-30',
#   'val': 70852000000,
#   'accn': '0001104659-10-053716',
#   'fy': 2010,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2010-10-26'},
#  {'start': '2010-01-01',
#   'end': '2010-09-30',
#   'val': 70852000000,
#   'accn': '0001104659-11-057630',
#   'fy': 2011,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2011-10-25'},
#  {'start': '2010-07-01',
#   'end': '2010-09-30',
#   'val': 24271000000,
#   'accn': '0001104659-10-053716',
#   'fy': 2010,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2010-10-26'},
#  {'start': '2010-07-01',
#   'end': '2010-09-30',
#   'val': 24271000000,
#   'accn': '0001104659-11-057630',
#   'fy': 2011,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2011-10-25',
#   'frame': 'CY2010Q3'},
#  {'start': '2009-12-31',
#   'end': '2010-12-31',
#   'val': 99870000000,
#   'accn': '0001047469-11-001117',
#   'fy': 2010,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2011-02-22'},
#  {'start': '2009-12-31',
#   'end': '2010-12-31',
#   'val': 99870000000,
#   'accn': '0001047469-12-001742',
#   'fy': 2011,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2012-02-28'},
#  {'start': '2009-12-31',
#   'end': '2010-12-31',
#   'val': 99870000000,
#   'accn': '0001047469-13-001698',
#   'fy': 2012,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2013-02-26',
#   'frame': 'CY2010'},
#  {'start': '2011-01-01',
#   'end': '2011-03-31',
#   'val': 24607000000,
#   'accn': '0001104659-11-022352',
#   'fy': 2011,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2011-04-26'},
#  {'start': '2011-01-01',
#   'end': '2011-03-31',
#   'val': 24607000000,
#   'accn': '0001104659-12-027715',
#   'fy': 2012,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2012-04-24',
#   'frame': 'CY2011Q1'},
#  {'start': '2011-01-01',
#   'end': '2011-06-30',
#   'val': 51273000000,
#   'accn': '0001104659-11-040759',
#   'fy': 2011,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2011-07-26'},
#  {'start': '2011-01-01',
#   'end': '2011-06-30',
#   'val': 51273000000,
#   'accn': '0001104659-12-052637',
#   'fy': 2012,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2012-07-31'},
#  {'start': '2011-04-01',
#   'end': '2011-06-30',
#   'val': 26666000000,
#   'accn': '0001104659-11-040759',
#   'fy': 2011,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2011-07-26'},
#  {'start': '2011-04-01',
#   'end': '2011-06-30',
#   'val': 26666000000,
#   'accn': '0001104659-12-052637',
#   'fy': 2012,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2012-07-31',
#   'frame': 'CY2011Q2'},
#  {'start': '2011-01-01',
#   'end': '2011-09-30',
#   'val': 77430000000,
#   'accn': '0001104659-11-057630',
#   'fy': 2011,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2011-10-25'},
#  {'start': '2011-01-01',
#   'end': '2011-09-30',
#   'val': 77430000000,
#   'accn': '0001104659-12-072210',
#   'fy': 2012,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2012-10-30'},
#  {'start': '2011-07-01',
#   'end': '2011-09-30',
#   'val': 26157000000,
#   'accn': '0001104659-11-057630',
#   'fy': 2011,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2011-10-25'},
#  {'start': '2011-07-01',
#   'end': '2011-09-30',
#   'val': 26157000000,
#   'accn': '0001104659-12-072210',
#   'fy': 2012,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2012-10-30',
#   'frame': 'CY2011Q3'},
#  {'start': '2010-12-31',
#   'end': '2011-12-31',
#   'val': 106916000000,
#   'accn': '0001047469-12-001742',
#   'fy': 2011,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2012-02-28'},
#  {'start': '2010-12-31',
#   'end': '2011-12-31',
#   'val': 106916000000,
#   'accn': '0001047469-13-001698',
#   'fy': 2012,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2013-02-26',
#   'frame': 'CY2011'},
#  {'start': '2011-01-01',
#   'end': '2011-12-31',
#   'val': 106916000000,
#   'accn': '0001047469-14-001302',
#   'fy': 2013,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2014-02-25'},
#  {'start': '2012-01-01',
#   'end': '2012-03-31',
#   'val': 24673000000,
#   'accn': '0001104659-12-027715',
#   'fy': 2012,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2012-04-24'},
#  {'start': '2012-01-01',
#   'end': '2012-03-31',
#   'val': 24673000000,
#   'accn': '0001104659-13-035106',
#   'fy': 2013,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2013-04-30',
#   'frame': 'CY2012Q1'},
#  {'start': '2012-01-01',
#   'end': '2012-06-30',
#   'val': 50456000000,
#   'accn': '0001104659-12-052637',
#   'fy': 2012,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2012-07-31'},
#  {'start': '2012-01-01',
#   'end': '2012-06-30',
#   'val': 50456000000,
#   'accn': '0001104659-13-058041',
#   'fy': 2013,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2013-07-31'},
#  {'start': '2012-04-01',
#   'end': '2012-06-30',
#   'val': 25783000000,
#   'accn': '0001104659-12-052637',
#   'fy': 2012,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2012-07-31'},
#  {'start': '2012-04-01',
#   'end': '2012-06-30',
#   'val': 25783000000,
#   'accn': '0001104659-13-058041',
#   'fy': 2013,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2013-07-31',
#   'frame': 'CY2012Q2'},
#  {'start': '2012-01-01',
#   'end': '2012-09-30',
#   'val': 75203000000,
#   'accn': '0001104659-12-072210',
#   'fy': 2012,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2012-10-30'},
#  {'start': '2012-01-01',
#   'end': '2012-09-30',
#   'val': 75203000000,
#   'accn': '0000051143-13-000007',
#   'fy': 2013,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2013-10-29'},
#  {'start': '2012-07-01',
#   'end': '2012-09-30',
#   'val': 24747000000,
#   'accn': '0001104659-12-072210',
#   'fy': 2012,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2012-10-30'},
#  {'start': '2012-07-01',
#   'end': '2012-09-30',
#   'val': 24747000000,
#   'accn': '0000051143-13-000007',
#   'fy': 2013,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2013-10-29',
#   'frame': 'CY2012Q3'},
#  {'start': '2012-01-01',
#   'end': '2012-12-31',
#   'val': 104507000000,
#   'accn': '0001047469-13-001698',
#   'fy': 2012,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2013-02-26'},
#  {'start': '2012-01-01',
#   'end': '2012-12-31',
#   'val': 104507000000,
#   'accn': '0001047469-14-001302',
#   'fy': 2013,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2014-02-25'},
#  {'start': '2012-01-01',
#   'end': '2012-12-31',
#   'val': 102874000000,
#   'accn': '0001047469-15-001106',
#   'fy': 2014,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2015-02-24',
#   'frame': 'CY2012'},
#  {'start': '2013-01-01',
#   'end': '2013-03-31',
#   'val': 23408000000,
#   'accn': '0001104659-13-035106',
#   'fy': 2013,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2013-04-30'},
#  {'start': '2013-01-01',
#   'end': '2013-03-31',
#   'val': 23408000000,
#   'accn': '0000051143-14-000004',
#   'fy': 2014,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2014-04-29',
#   'frame': 'CY2013Q1'},
#  {'start': '2013-01-01',
#   'end': '2013-06-30',
#   'val': 48332000000,
#   'accn': '0001104659-13-058041',
#   'fy': 2013,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2013-07-31'},
#  {'start': '2013-01-01',
#   'end': '2013-06-30',
#   'val': 48332000000,
#   'accn': '0000051143-14-000007',
#   'fy': 2014,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2014-07-29'},
#  {'start': '2013-04-01',
#   'end': '2013-06-30',
#   'val': 24924000000,
#   'accn': '0001104659-13-058041',
#   'fy': 2013,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2013-07-31'},
#  {'start': '2013-04-01',
#   'end': '2013-06-30',
#   'val': 24924000000,
#   'accn': '0000051143-14-000007',
#   'fy': 2014,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2014-07-29',
#   'frame': 'CY2013Q2'},
#  {'start': '2013-01-01',
#   'end': '2013-09-30',
#   'val': 72052000000,
#   'accn': '0000051143-13-000007',
#   'fy': 2013,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2013-10-29'},
#  {'start': '2013-01-01',
#   'end': '2013-09-30',
#   'val': 70982000000,
#   'accn': '0000051143-14-000010',
#   'fy': 2014,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2014-10-28'},
#  {'start': '2013-07-01',
#   'end': '2013-09-30',
#   'val': 23720000000,
#   'accn': '0000051143-13-000007',
#   'fy': 2013,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2013-10-29'},
#  {'start': '2013-07-01',
#   'end': '2013-09-30',
#   'val': 23338000000,
#   'accn': '0000051143-14-000010',
#   'fy': 2014,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2014-10-28',
#   'frame': 'CY2013Q3'},
#  {'start': '2013-01-01',
#   'end': '2013-12-31',
#   'val': 99751000000,
#   'accn': '0001047469-14-001302',
#   'fy': 2013,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2014-02-25'},
#  {'start': '2013-01-01',
#   'end': '2013-12-31',
#   'val': 98367000000,
#   'accn': '0001047469-15-001106',
#   'fy': 2014,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2015-02-24'},
#  {'start': '2013-01-01',
#   'end': '2013-12-31',
#   'val': 98367000000,
#   'accn': '0001047469-16-010329',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2016-02-23'},
#  {'start': '2013-01-01',
#   'end': '2013-12-31',
#   'val': 98367000000,
#   'accn': '0001104659-16-126857',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '8-K',
#   'filed': '2016-06-13',
#   'frame': 'CY2013'},
#  {'start': '2014-01-01',
#   'end': '2014-03-31',
#   'val': 22484000000,
#   'accn': '0000051143-14-000004',
#   'fy': 2014,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2014-04-29'},
#  {'start': '2014-01-01',
#   'end': '2014-03-31',
#   'val': 22236000000,
#   'accn': '0000051143-15-000003',
#   'fy': 2015,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2015-04-28',
#   'frame': 'CY2014Q1'},
#  {'start': '2014-01-01',
#   'end': '2014-06-30',
#   'val': 46848000000,
#   'accn': '0000051143-14-000007',
#   'fy': 2014,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2014-07-29'},
#  {'start': '2014-01-01',
#   'end': '2014-06-30',
#   'val': 46283000000,
#   'accn': '0000051143-15-000005',
#   'fy': 2015,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2015-07-28'},
#  {'start': '2014-04-01',
#   'end': '2014-06-30',
#   'val': 24364000000,
#   'accn': '0000051143-14-000007',
#   'fy': 2014,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2014-07-29'},
#  {'start': '2014-04-01',
#   'end': '2014-06-30',
#   'val': 24047000000,
#   'accn': '0000051143-15-000005',
#   'fy': 2015,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2015-07-28',
#   'frame': 'CY2014Q2'},
#  {'start': '2014-01-01',
#   'end': '2014-09-30',
#   'val': 68680000000,
#   'accn': '0000051143-14-000010',
#   'fy': 2014,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2014-10-28'},
#  {'start': '2014-01-01',
#   'end': '2014-09-30',
#   'val': 68680000000,
#   'accn': '0000051143-15-000009',
#   'fy': 2015,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2015-10-27'},
#  {'start': '2014-07-01',
#   'end': '2014-09-30',
#   'val': 22397000000,
#   'accn': '0000051143-14-000010',
#   'fy': 2014,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2014-10-28'},
#  {'start': '2014-07-01',
#   'end': '2014-09-30',
#   'val': 22397000000,
#   'accn': '0000051143-15-000009',
#   'fy': 2015,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2015-10-27',
#   'frame': 'CY2014Q3'},
#  {'start': '2014-01-01',
#   'end': '2014-12-31',
#   'val': 92793000000,
#   'accn': '0001047469-15-001106',
#   'fy': 2014,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2015-02-24'},
#  {'start': '2014-01-01',
#   'end': '2014-12-31',
#   'val': 92793000000,
#   'accn': '0001047469-16-010329',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2016-02-23'},
#  {'start': '2014-01-01',
#   'end': '2014-12-31',
#   'val': 92793000000,
#   'accn': '0001104659-16-126857',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '8-K',
#   'filed': '2016-06-13'},
#  {'start': '2014-01-01',
#   'end': '2014-12-31',
#   'val': 92793000000,
#   'accn': '0001047469-17-001061',
#   'fy': 2016,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2017-02-28',
#   'frame': 'CY2014'},
#  {'start': '2015-01-01',
#   'end': '2015-03-31',
#   'val': 19590000000,
#   'accn': '0000051143-15-000003',
#   'fy': 2015,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2015-04-28'},
#  {'start': '2015-01-01',
#   'end': '2015-03-31',
#   'val': 19590000000,
#   'accn': '0000051143-16-000013',
#   'fy': 2016,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2016-04-26',
#   'frame': 'CY2015Q1'},
#  {'start': '2015-01-01',
#   'end': '2015-06-30',
#   'val': 40403000000,
#   'accn': '0000051143-15-000005',
#   'fy': 2015,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2015-07-28'},
#  {'start': '2015-01-01',
#   'end': '2015-06-30',
#   'val': 40403000000,
#   'accn': '0001104659-16-134367',
#   'fy': 2016,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2016-07-26'},
#  {'start': '2015-04-01',
#   'end': '2015-06-30',
#   'val': 20813000000,
#   'accn': '0000051143-15-000005',
#   'fy': 2015,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2015-07-28'},
#  {'start': '2015-04-01',
#   'end': '2015-06-30',
#   'val': 20813000000,
#   'accn': '0001104659-16-134367',
#   'fy': 2016,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2016-07-26',
#   'frame': 'CY2015Q2'},
#  {'start': '2015-01-01',
#   'end': '2015-09-30',
#   'val': 59682000000,
#   'accn': '0000051143-15-000009',
#   'fy': 2015,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2015-10-27'},
#  {'start': '2015-01-01',
#   'end': '2015-09-30',
#   'val': 59682000000,
#   'accn': '0001104659-16-151931',
#   'fy': 2016,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2016-10-25'},
#  {'start': '2015-07-01',
#   'end': '2015-09-30',
#   'val': 19280000000,
#   'accn': '0000051143-15-000009',
#   'fy': 2015,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2015-10-27'},
#  {'start': '2015-07-01',
#   'end': '2015-09-30',
#   'val': 19280000000,
#   'accn': '0001104659-16-151931',
#   'fy': 2016,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2016-10-25',
#   'frame': 'CY2015Q3'},
#  {'start': '2015-01-01',
#   'end': '2015-12-31',
#   'val': 81741000000,
#   'accn': '0001047469-16-010329',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2016-02-23'},
#  {'start': '2015-01-01',
#   'end': '2015-12-31',
#   'val': 81741000000,
#   'accn': '0001104659-16-126857',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '8-K',
#   'filed': '2016-06-13'},
#  {'start': '2015-01-01',
#   'end': '2015-12-31',
#   'val': 81741000000,
#   'accn': '0001047469-17-001061',
#   'fy': 2016,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2017-02-28'},
#  {'start': '2015-01-01',
#   'end': '2015-12-31',
#   'val': 81741000000,
#   'accn': '0001047469-18-001117',
#   'fy': 2017,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2018-02-27',
#   'frame': 'CY2015'},
#  {'start': '2016-01-01',
#   'end': '2016-03-31',
#   'val': 18684000000,
#   'accn': '0000051143-16-000013',
#   'fy': 2016,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2016-04-26'},
#  {'start': '2016-01-01',
#   'end': '2016-03-31',
#   'val': 18684000000,
#   'accn': '0001104659-17-025881',
#   'fy': 2017,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2017-04-25',
#   'frame': 'CY2016Q1'},
#  {'start': '2016-01-01',
#   'end': '2016-06-30',
#   'val': 38923000000,
#   'accn': '0001104659-16-134367',
#   'fy': 2016,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2016-07-26'},
#  {'start': '2016-01-01',
#   'end': '2016-06-30',
#   'val': 38923000000,
#   'accn': '0001104659-17-046808',
#   'fy': 2017,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2017-07-25'},
#  {'start': '2016-04-01',
#   'end': '2016-06-30',
#   'val': 20238000000,
#   'accn': '0001104659-16-134367',
#   'fy': 2016,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2016-07-26'},
#  {'start': '2016-04-01',
#   'end': '2016-06-30',
#   'val': 20238000000,
#   'accn': '0001104659-17-046808',
#   'fy': 2017,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2017-07-25',
#   'frame': 'CY2016Q2'},
#  {'start': '2016-01-01',
#   'end': '2016-09-30',
#   'val': 58149000000,
#   'accn': '0001104659-16-151931',
#   'fy': 2016,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2016-10-25'},
#  {'start': '2016-01-01',
#   'end': '2016-09-30',
#   'val': 58149000000,
#   'accn': '0001104659-17-064968',
#   'fy': 2017,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2017-10-31'},
#  {'start': '2016-07-01',
#   'end': '2016-09-30',
#   'val': 19226000000,
#   'accn': '0001104659-16-151931',
#   'fy': 2016,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2016-10-25'},
#  {'start': '2016-07-01',
#   'end': '2016-09-30',
#   'val': 19226000000,
#   'accn': '0001104659-17-064968',
#   'fy': 2017,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2017-10-31',
#   'frame': 'CY2016Q3'},
#  {'start': '2016-01-01',
#   'end': '2016-12-31',
#   'val': 79919000000,
#   'accn': '0001047469-17-001061',
#   'fy': 2016,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2017-02-28'},
#  {'start': '2016-01-01',
#   'end': '2016-12-31',
#   'val': 79919000000,
#   'accn': '0001047469-18-001117',
#   'fy': 2017,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2018-02-27'},
#  {'start': '2016-01-01',
#   'end': '2016-12-31',
#   'val': 79919000000,
#   'accn': '0001047469-19-000712',
#   'fy': 2018,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2019-02-26',
#   'frame': 'CY2016'},
#  {'start': '2017-01-01',
#   'end': '2017-03-31',
#   'val': 18155000000,
#   'accn': '0001104659-17-025881',
#   'fy': 2017,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2017-04-25'},
#  {'start': '2017-01-01',
#   'end': '2017-03-31',
#   'val': 18155000000,
#   'accn': '0001104659-18-026178',
#   'fy': 2018,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2018-04-24',
#   'frame': 'CY2017Q1'},
#  {'start': '2017-01-01',
#   'end': '2017-06-30',
#   'val': 37443000000,
#   'accn': '0001104659-17-046808',
#   'fy': 2017,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2017-07-25'},
#  {'start': '2017-01-01',
#   'end': '2017-06-30',
#   'val': 37443000000,
#   'accn': '0001104659-18-048404',
#   'fy': 2018,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2018-07-31'},
#  {'start': '2017-04-01',
#   'end': '2017-06-30',
#   'val': 19289000000,
#   'accn': '0001104659-17-046808',
#   'fy': 2017,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2017-07-25'},
#  {'start': '2017-04-01',
#   'end': '2017-06-30',
#   'val': 19289000000,
#   'accn': '0001104659-18-048404',
#   'fy': 2018,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2018-07-31',
#   'frame': 'CY2017Q2'},
#  {'start': '2017-01-01',
#   'end': '2017-09-30',
#   'val': 56597000000,
#   'accn': '0001104659-17-064968',
#   'fy': 2017,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2017-10-31'},
#  {'start': '2017-01-01',
#   'end': '2017-09-30',
#   'val': 56597000000,
#   'accn': '0001104659-18-064673',
#   'fy': 2018,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2018-10-30'},
#  {'start': '2017-07-01',
#   'end': '2017-09-30',
#   'val': 19153000000,
#   'accn': '0001104659-17-064968',
#   'fy': 2017,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2017-10-31'},
#  {'start': '2017-07-01',
#   'end': '2017-09-30',
#   'val': 19153000000,
#   'accn': '0001104659-18-064673',
#   'fy': 2018,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2018-10-30',
#   'frame': 'CY2017Q3'},
#  {'start': '2017-01-01',
#   'end': '2017-12-31',
#   'val': 79139000000,
#   'accn': '0001047469-18-001117',
#   'fy': 2017,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2018-02-27'},
#  {'start': '2017-01-01',
#   'end': '2017-12-31',
#   'val': 79139000000,
#   'accn': '0001047469-19-000712',
#   'fy': 2018,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2019-02-26'},
#  {'start': '2017-01-01',
#   'end': '2017-12-31',
#   'val': 79139000000,
#   'accn': '0001558370-20-001334',
#   'fy': 2019,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2020-02-25',
#   'frame': 'CY2017'},
#  {'start': '2018-01-01',
#   'end': '2018-03-31',
#   'val': 19072000000,
#   'accn': '0001104659-18-026178',
#   'fy': 2018,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2018-04-24'},
#  {'start': '2018-01-01',
#   'end': '2018-03-31',
#   'val': 19072000000,
#   'accn': '0001104659-19-025328',
#   'fy': 2019,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2019-04-30',
#   'frame': 'CY2018Q1'},
#  {'start': '2018-01-01',
#   'end': '2018-06-30',
#   'val': 39075000000,
#   'accn': '0001104659-18-048404',
#   'fy': 2018,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2018-07-31'},
#  {'start': '2018-01-01',
#   'end': '2018-06-30',
#   'val': 39075000000,
#   'accn': '0001558370-19-006560',
#   'fy': 2019,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2019-07-30'},
#  {'start': '2018-04-01',
#   'end': '2018-06-30',
#   'val': 20003000000,
#   'accn': '0001104659-18-048404',
#   'fy': 2018,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2018-07-31'},
#  {'start': '2018-04-01',
#   'end': '2018-06-30',
#   'val': 20003000000,
#   'accn': '0001558370-19-006560',
#   'fy': 2019,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2019-07-30',
#   'frame': 'CY2018Q2'},
#  {'start': '2018-01-01',
#   'end': '2018-09-30',
#   'val': 57830000000,
#   'accn': '0001104659-18-064673',
#   'fy': 2018,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2018-10-30'},
#  {'start': '2018-01-01',
#   'end': '2018-09-30',
#   'val': 57830000000,
#   'accn': '0001558370-19-009324',
#   'fy': 2019,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2019-10-30'},
#  {'start': '2018-07-01',
#   'end': '2018-09-30',
#   'val': 18756000000,
#   'accn': '0001104659-18-064673',
#   'fy': 2018,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2018-10-30'},
#  {'start': '2018-07-01',
#   'end': '2018-09-30',
#   'val': 18756000000,
#   'accn': '0001558370-19-009324',
#   'fy': 2019,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2019-10-30',
#   'frame': 'CY2018Q3'},
#  {'start': '2018-01-01',
#   'end': '2018-12-31',
#   'val': 79591000000,
#   'accn': '0001047469-19-000712',
#   'fy': 2018,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2019-02-26'},
#  {'start': '2018-01-01',
#   'end': '2018-12-31',
#   'val': 79591000000,
#   'accn': '0001558370-20-001334',
#   'fy': 2019,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2020-02-25'},
#  {'start': '2018-01-01',
#   'end': '2018-12-31',
#   'val': 79591000000,
#   'accn': '0001558370-21-001489',
#   'fy': 2020,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2021-02-23',
#   'frame': 'CY2018'},
#  {'start': '2019-01-01',
#   'end': '2019-03-31',
#   'val': 18182000000,
#   'accn': '0001104659-19-025328',
#   'fy': 2019,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2019-04-30'},
#  {'start': '2019-01-01',
#   'end': '2019-03-31',
#   'val': 18182000000,
#   'accn': '0001558370-20-004491',
#   'fy': 2020,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2020-04-28',
#   'frame': 'CY2019Q1'},
#  {'start': '2019-01-01',
#   'end': '2019-06-30',
#   'val': 37342000000,
#   'accn': '0001558370-19-006560',
#   'fy': 2019,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2019-07-30'},
#  {'start': '2019-01-01',
#   'end': '2019-06-30',
#   'val': 37342000000,
#   'accn': '0001558370-20-008516',
#   'fy': 2020,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2020-07-28'},
#  {'start': '2019-04-01',
#   'end': '2019-06-30',
#   'val': 19161000000,
#   'accn': '0001558370-19-006560',
#   'fy': 2019,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2019-07-30'},
#  {'start': '2019-04-01',
#   'end': '2019-06-30',
#   'val': 19161000000,
#   'accn': '0001558370-20-008516',
#   'fy': 2020,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2020-07-28',
#   'frame': 'CY2019Q2'},
#  {'start': '2019-01-01',
#   'end': '2019-09-30',
#   'val': 55370000000,
#   'accn': '0001558370-19-009324',
#   'fy': 2019,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2019-10-30'},
#  {'start': '2019-01-01',
#   'end': '2019-09-30',
#   'val': 55370000000,
#   'accn': '0001558370-20-011799',
#   'fy': 2020,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2020-10-27'},
#  {'start': '2019-07-01',
#   'end': '2019-09-30',
#   'val': 18028000000,
#   'accn': '0001558370-19-009324',
#   'fy': 2019,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2019-10-30'},
#  {'start': '2019-07-01',
#   'end': '2019-09-30',
#   'val': 18028000000,
#   'accn': '0001558370-20-011799',
#   'fy': 2020,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2020-10-27',
#   'frame': 'CY2019Q3'},
#  {'start': '2019-01-01',
#   'end': '2019-12-31',
#   'val': 77147000000,
#   'accn': '0001558370-20-001334',
#   'fy': 2019,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2020-02-25'},
#  {'start': '2019-01-01',
#   'end': '2019-12-31',
#   'val': 77000000000,
#   'accn': '0001558370-20-004491',
#   'fy': 2020,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2020-04-28'},
#  {'start': '2019-01-01',
#   'end': '2019-12-31',
#   'val': 77000000000,
#   'accn': '0001558370-20-008516',
#   'fy': 2020,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2020-07-28'},
#  {'start': '2019-01-01',
#   'end': '2019-12-31',
#   'val': 77000000000,
#   'accn': '0001558370-20-011799',
#   'fy': 2020,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2020-10-27'},
#  {'start': '2019-01-01',
#   'end': '2019-12-31',
#   'val': 77147000000,
#   'accn': '0001558370-21-001489',
#   'fy': 2020,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2021-02-23'},
#  {'start': '2019-01-01',
#   'end': '2019-12-31',
#   'val': 57714000000,
#   'accn': '0001558370-22-001584',
#   'fy': 2021,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2022-02-22',
#   'frame': 'CY2019'},
#  {'start': '2020-01-01',
#   'end': '2020-03-31',
#   'val': 17571000000,
#   'accn': '0001558370-20-004491',
#   'fy': 2020,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2020-04-28'},
#  {'start': '2020-01-01',
#   'end': '2020-03-31',
#   'val': 17571000000,
#   'accn': '0001558370-21-004922',
#   'fy': 2021,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2021-04-27',
#   'frame': 'CY2020Q1'},
#  {'start': '2020-01-01',
#   'end': '2020-06-30',
#   'val': 35694000000,
#   'accn': '0001558370-20-008516',
#   'fy': 2020,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2020-07-28'},
#  {'start': '2020-01-01',
#   'end': '2020-06-30',
#   'val': 35694000000,
#   'accn': '0001558370-21-009351',
#   'fy': 2021,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2021-07-27'},
#  {'start': '2020-04-01',
#   'end': '2020-06-30',
#   'val': 18123000000,
#   'accn': '0001558370-20-008516',
#   'fy': 2020,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2020-07-28'},
#  {'start': '2020-04-01',
#   'end': '2020-06-30',
#   'val': 18123000000,
#   'accn': '0001558370-21-009351',
#   'fy': 2021,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2021-07-27',
#   'frame': 'CY2020Q2'},
#  {'start': '2020-01-01',
#   'end': '2020-09-30',
#   'val': 53253000000,
#   'accn': '0001558370-20-011799',
#   'fy': 2020,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2020-10-27'},
#  {'start': '2020-01-01',
#   'end': '2020-09-30',
#   'val': 53253000000,
#   'accn': '0001558370-21-014734',
#   'fy': 2021,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2021-11-05'},
#  {'start': '2020-07-01',
#   'end': '2020-09-30',
#   'val': 17560000000,
#   'accn': '0001558370-20-011799',
#   'fy': 2020,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2020-10-27'},
#  {'start': '2020-07-01',
#   'end': '2020-09-30',
#   'val': 17560000000,
#   'accn': '0001558370-21-014734',
#   'fy': 2021,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2021-11-05',
#   'frame': 'CY2020Q3'},
#  {'start': '2020-01-01',
#   'end': '2020-12-31',
#   'val': 73620000000,
#   'accn': '0001558370-21-001489',
#   'fy': 2020,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2021-02-23'},
#  {'start': '2020-01-01',
#   'end': '2020-12-31',
#   'val': 55179000000,
#   'accn': '0001558370-22-001584',
#   'fy': 2021,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2022-02-22',
#   'frame': 'CY2020'},
#  {'start': '2021-01-01',
#   'end': '2021-03-31',
#   'val': 17730000000,
#   'accn': '0001558370-21-004922',
#   'fy': 2021,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2021-04-27'},
#  {'start': '2021-01-01',
#   'end': '2021-03-31',
#   'val': 13187000000,
#   'accn': '0001558370-22-005983',
#   'fy': 2022,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2022-04-26',
#   'frame': 'CY2021Q1'},
#  {'start': '2021-01-01',
#   'end': '2021-06-30',
#   'val': 36474000000,
#   'accn': '0001558370-21-009351',
#   'fy': 2021,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2021-07-27'},
#  {'start': '2021-04-01',
#   'end': '2021-06-30',
#   'val': 18745000000,
#   'accn': '0001558370-21-009351',
#   'fy': 2021,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2021-07-27',
#   'frame': 'CY2021Q2'},
#  {'start': '2021-01-01',
#   'end': '2021-09-30',
#   'val': 54093000000,
#   'accn': '0001558370-21-014734',
#   'fy': 2021,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2021-11-05'},
#  {'start': '2021-07-01',
#   'end': '2021-09-30',
#   'val': 17618000000,
#   'accn': '0001558370-21-014734',
#   'fy': 2021,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2021-11-05',
#   'frame': 'CY2021Q3'},
#  {'start': '2021-01-01',
#   'end': '2021-12-31',
#   'val': 57350000000,
#   'accn': '0001558370-22-001584',
#   'fy': 2021,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2022-02-22',
#   'frame': 'CY2021'},
#  {'start': '2022-01-01',
#   'end': '2022-03-31',
#   'val': 14197000000,
#   'accn': '0001558370-22-005983',
#   'fy': 2022,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2022-04-26',
#   'frame': 'CY2022Q1'}]

# %%
pd.DataFrame(gaap["Assets"]["units"]["USD"])
# Out:
#             end           val                  accn    fy  fp  form  \
# 0    2008-12-31  109524000000  0001104659-09-045198  2009  Q2  10-Q
# 1    2008-12-31  109524000000  0001104659-09-060554  2009  Q3  10-Q
# 2    2008-12-31  109524000000  0001047469-10-001151  2009  FY  10-K
# 3    2008-12-31  109524000000  0001047469-11-001117  2010  FY  10-K
# 4    2009-06-30  103655000000  0001104659-09-045198  2009  Q2  10-Q
# ..          ...           ...                   ...   ...  ..   ...
# 114  2021-06-30  146814000000  0001558370-21-009351  2021  Q2  10-Q
# 115  2021-09-30  144214000000  0001558370-21-014734  2021  Q3  10-Q
# 116  2021-12-31  132001000000  0001558370-22-001584  2021  FY  10-K
# 117  2021-12-31  132001000000  0001558370-22-005983  2022  Q1  10-Q
# 118  2022-03-31  133275000000  0001558370-22-005983  2022  Q1  10-Q
#
#           filed      frame
# 0    2009-07-28        NaN
# 1    2009-10-27        NaN
# 2    2010-02-23        NaN
# 3    2011-02-22  CY2008Q4I
# 4    2009-07-28  CY2009Q2I
# ..          ...        ...
# 114  2021-07-27  CY2021Q2I
# 115  2021-11-05  CY2021Q3I
# 116  2022-02-22        NaN
# 117  2022-04-26  CY2021Q4I
# 118  2022-04-26  CY2022Q1I
#
# [119 rows x 8 columns]

# %%
frame = pd.DataFrame(keyQuarters(gaap["Revenues"]["units"]["USD"]))
frame = frame[["fy", "val", "frame", "form"]]
# frame = frame.append(make_q4(frame))
frame
# make_q4(consolidate())
# Out:
#       fy           val     frame  form
# 0   2009   98786000000    CY2007  10-K
# 1   2009   26820000000  CY2008Q2  10-Q
# 2   2009   25302000000  CY2008Q3  10-Q
# 3   2010  103630000000    CY2008  10-K
# 4   2010   21711000000  CY2009Q1  10-Q
# 5   2010   23250000000  CY2009Q2  10-Q
# 6   2010   23566000000  CY2009Q3  10-Q
# 7   2011   95758000000    CY2009  10-K
# 8   2011   22857000000  CY2010Q1  10-Q
# 9   2011   23724000000  CY2010Q2  10-Q
# 10  2011   24271000000  CY2010Q3  10-Q
# 11  2012   99870000000    CY2010  10-K
# 12  2012   24607000000  CY2011Q1  10-Q
# 13  2012   26666000000  CY2011Q2  10-Q
# 14  2012   26157000000  CY2011Q3  10-Q
# 15  2012  106916000000    CY2011  10-K
# 16  2013   24673000000  CY2012Q1  10-Q
# 17  2013   25783000000  CY2012Q2  10-Q
# 18  2013   24747000000  CY2012Q3  10-Q
# 19  2014  102874000000    CY2012  10-K
# 20  2014   23408000000  CY2013Q1  10-Q
# 21  2014   24924000000  CY2013Q2  10-Q
# 22  2014   23338000000  CY2013Q3  10-Q
# 23  2015   98367000000    CY2013   8-K
# 24  2015   22236000000  CY2014Q1  10-Q
# 25  2015   24047000000  CY2014Q2  10-Q
# 26  2015   22397000000  CY2014Q3  10-Q
# 27  2016   92793000000    CY2014  10-K
# 28  2016   19590000000  CY2015Q1  10-Q
# 29  2016   20813000000  CY2015Q2  10-Q
# 30  2016   19280000000  CY2015Q3  10-Q
# 31  2017   81741000000    CY2015  10-K
# 32  2017   18684000000  CY2016Q1  10-Q
# 33  2017   20238000000  CY2016Q2  10-Q
# 34  2017   19226000000  CY2016Q3  10-Q
# 35  2018   79919000000    CY2016  10-K
# 36  2018   18155000000  CY2017Q1  10-Q
# 37  2018   19289000000  CY2017Q2  10-Q
# 38  2018   19153000000  CY2017Q3  10-Q
# 39  2019   79139000000    CY2017  10-K
# 40  2019   19072000000  CY2018Q1  10-Q
# 41  2019   20003000000  CY2018Q2  10-Q
# 42  2019   18756000000  CY2018Q3  10-Q
# 43  2020   79591000000    CY2018  10-K
# 44  2020   18182000000  CY2019Q1  10-Q
# 45  2020   19161000000  CY2019Q2  10-Q
# 46  2020   18028000000  CY2019Q3  10-Q
# 47  2021   57714000000    CY2019  10-K
# 48  2021   17571000000  CY2020Q1  10-Q
# 49  2021   18123000000  CY2020Q2  10-Q
# 50  2021   17560000000  CY2020Q3  10-Q
# 51  2021   55179000000    CY2020  10-K
# 52  2022   13187000000  CY2021Q1  10-Q
# 53  2021   18745000000  CY2021Q2  10-Q
# 54  2021   17618000000  CY2021Q3  10-Q
# 55  2021   57350000000    CY2021  10-K
# 56  2022   14197000000  CY2022Q1  10-Q

# %%
gaap["Assets"]["units"]["USD"]
# Out:
# [{'end': '2008-12-31',
#   'val': 109524000000,
#   'accn': '0001104659-09-045198',
#   'fy': 2009,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2009-07-28'},
#  {'end': '2008-12-31',
#   'val': 109524000000,
#   'accn': '0001104659-09-060554',
#   'fy': 2009,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2009-10-27'},
#  {'end': '2008-12-31',
#   'val': 109524000000,
#   'accn': '0001047469-10-001151',
#   'fy': 2009,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2010-02-23'},
#  {'end': '2008-12-31',
#   'val': 109524000000,
#   'accn': '0001047469-11-001117',
#   'fy': 2010,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2011-02-22',
#   'frame': 'CY2008Q4I'},
#  {'end': '2009-06-30',
#   'val': 103655000000,
#   'accn': '0001104659-09-045198',
#   'fy': 2009,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2009-07-28',
#   'frame': 'CY2009Q2I'},
#  {'end': '2009-09-30',
#   'val': 103675000000,
#   'accn': '0001104659-09-060554',
#   'fy': 2009,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2009-10-27',
#   'frame': 'CY2009Q3I'},
#  {'end': '2009-12-31',
#   'val': 109022000000,
#   'accn': '0001047469-10-001151',
#   'fy': 2009,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2010-02-23'},
#  {'end': '2009-12-31',
#   'val': 109022000000,
#   'accn': '0001104659-10-022064',
#   'fy': 2010,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2010-04-27'},
#  {'end': '2009-12-31',
#   'val': 109022000000,
#   'accn': '0001104659-10-039808',
#   'fy': 2010,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2010-07-27'},
#  {'end': '2009-12-31',
#   'val': 109022000000,
#   'accn': '0001104659-10-053716',
#   'fy': 2010,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2010-10-26'},
#  {'end': '2009-12-31',
#   'val': 109022000000,
#   'accn': '0001047469-11-001117',
#   'fy': 2010,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2011-02-22'},
#  {'end': '2009-12-31',
#   'val': 109022000000,
#   'accn': '0001047469-12-001742',
#   'fy': 2011,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2012-02-28',
#   'frame': 'CY2009Q4I'},
#  {'end': '2010-03-31',
#   'val': 105208000000,
#   'accn': '0001104659-10-022064',
#   'fy': 2010,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2010-04-27',
#   'frame': 'CY2010Q1I'},
#  {'end': '2010-06-30',
#   'val': 103420000000,
#   'accn': '0001104659-10-039808',
#   'fy': 2010,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2010-07-27',
#   'frame': 'CY2010Q2I'},
#  {'end': '2010-09-30',
#   'val': 107174000000,
#   'accn': '0001104659-10-053716',
#   'fy': 2010,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2010-10-26',
#   'frame': 'CY2010Q3I'},
#  {'end': '2010-12-31',
#   'val': 113452000000,
#   'accn': '0001047469-11-001117',
#   'fy': 2010,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2011-02-22'},
#  {'end': '2010-12-31',
#   'val': 113452000000,
#   'accn': '0001104659-11-022352',
#   'fy': 2011,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2011-04-26'},
#  {'end': '2010-12-31',
#   'val': 113452000000,
#   'accn': '0001104659-11-040759',
#   'fy': 2011,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2011-07-26'},
#  {'end': '2010-12-31',
#   'val': 113452000000,
#   'accn': '0001104659-11-057630',
#   'fy': 2011,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2011-10-25'},
#  {'end': '2010-12-31',
#   'val': 113452000000,
#   'accn': '0001047469-12-001742',
#   'fy': 2011,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2012-02-28'},
#  {'end': '2010-12-31',
#   'val': 113452000000,
#   'accn': '0001047469-13-001698',
#   'fy': 2012,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2013-02-26',
#   'frame': 'CY2010Q4I'},
#  {'end': '2011-03-31',
#   'val': 112960000000,
#   'accn': '0001104659-11-022352',
#   'fy': 2011,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2011-04-26',
#   'frame': 'CY2011Q1I'},
#  {'end': '2011-06-30',
#   'val': 113474000000,
#   'accn': '0001104659-11-040759',
#   'fy': 2011,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2011-07-26',
#   'frame': 'CY2011Q2I'},
#  {'end': '2011-09-30',
#   'val': 110158000000,
#   'accn': '0001104659-11-057630',
#   'fy': 2011,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2011-10-25',
#   'frame': 'CY2011Q3I'},
#  {'end': '2011-12-31',
#   'val': 116433000000,
#   'accn': '0001047469-12-001742',
#   'fy': 2011,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2012-02-28'},
#  {'end': '2011-12-31',
#   'val': 116433000000,
#   'accn': '0001104659-12-027715',
#   'fy': 2012,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2012-04-24'},
#  {'end': '2011-12-31',
#   'val': 116433000000,
#   'accn': '0001104659-12-052637',
#   'fy': 2012,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2012-07-31'},
#  {'end': '2011-12-31',
#   'val': 116433000000,
#   'accn': '0001104659-12-072210',
#   'fy': 2012,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2012-10-30'},
#  {'end': '2011-12-31',
#   'val': 116433000000,
#   'accn': '0001047469-13-001698',
#   'fy': 2012,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2013-02-26'},
#  {'end': '2011-12-31',
#   'val': 116433000000,
#   'accn': '0001047469-14-001302',
#   'fy': 2013,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2014-02-25',
#   'frame': 'CY2011Q4I'},
#  {'end': '2012-03-31',
#   'val': 115347000000,
#   'accn': '0001104659-12-027715',
#   'fy': 2012,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2012-04-24',
#   'frame': 'CY2012Q1I'},
#  {'end': '2012-06-30',
#   'val': 113832000000,
#   'accn': '0001104659-12-052637',
#   'fy': 2012,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2012-07-31',
#   'frame': 'CY2012Q2I'},
#  {'end': '2012-09-30',
#   'val': 115778000000,
#   'accn': '0001104659-12-072210',
#   'fy': 2012,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2012-10-30',
#   'frame': 'CY2012Q3I'},
#  {'end': '2012-12-31',
#   'val': 119213000000,
#   'accn': '0001047469-13-001698',
#   'fy': 2012,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2013-02-26'},
#  {'end': '2012-12-31',
#   'val': 119213000000,
#   'accn': '0001104659-13-035106',
#   'fy': 2013,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2013-04-30'},
#  {'end': '2012-12-31',
#   'val': 119213000000,
#   'accn': '0001104659-13-058041',
#   'fy': 2013,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2013-07-31'},
#  {'end': '2012-12-31',
#   'val': 119213000000,
#   'accn': '0000051143-13-000007',
#   'fy': 2013,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2013-10-29'},
#  {'end': '2012-12-31',
#   'val': 119213000000,
#   'accn': '0001047469-14-001302',
#   'fy': 2013,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2014-02-25'},
#  {'end': '2012-12-31',
#   'val': 119213000000,
#   'accn': '0001047469-15-001106',
#   'fy': 2014,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2015-02-24',
#   'frame': 'CY2012Q4I'},
#  {'end': '2013-03-31',
#   'val': 117258000000,
#   'accn': '0001104659-13-035106',
#   'fy': 2013,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2013-04-30',
#   'frame': 'CY2013Q1I'},
#  {'end': '2013-06-30',
#   'val': 115153000000,
#   'accn': '0001104659-13-058041',
#   'fy': 2013,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2013-07-31',
#   'frame': 'CY2013Q2I'},
#  {'end': '2013-09-30',
#   'val': 117845000000,
#   'accn': '0000051143-13-000007',
#   'fy': 2013,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2013-10-29',
#   'frame': 'CY2013Q3I'},
#  {'end': '2013-12-31',
#   'val': 126223000000,
#   'accn': '0001047469-14-001302',
#   'fy': 2013,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2014-02-25'},
#  {'end': '2013-12-31',
#   'val': 126223000000,
#   'accn': '0000051143-14-000004',
#   'fy': 2014,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2014-04-29'},
#  {'end': '2013-12-31',
#   'val': 126223000000,
#   'accn': '0000051143-14-000007',
#   'fy': 2014,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2014-07-29'},
#  {'end': '2013-12-31',
#   'val': 126223000000,
#   'accn': '0000051143-14-000010',
#   'fy': 2014,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2014-10-28'},
#  {'end': '2013-12-31',
#   'val': 126223000000,
#   'accn': '0001047469-15-001106',
#   'fy': 2014,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2015-02-24'},
#  {'end': '2013-12-31',
#   'val': 125641000000,
#   'accn': '0001047469-16-010329',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2016-02-23'},
#  {'end': '2013-12-31',
#   'val': 125641000000,
#   'accn': '0001104659-16-126857',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '8-K',
#   'filed': '2016-06-13',
#   'frame': 'CY2013Q4I'},
#  {'end': '2014-03-31',
#   'val': 122646000000,
#   'accn': '0000051143-14-000004',
#   'fy': 2014,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2014-04-29',
#   'frame': 'CY2014Q1I'},
#  {'end': '2014-06-30',
#   'val': 124314000000,
#   'accn': '0000051143-14-000007',
#   'fy': 2014,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2014-07-29',
#   'frame': 'CY2014Q2I'},
#  {'end': '2014-09-30',
#   'val': 118911000000,
#   'accn': '0000051143-14-000010',
#   'fy': 2014,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2014-10-28',
#   'frame': 'CY2014Q3I'},
#  {'end': '2014-12-31',
#   'val': 117532000000,
#   'accn': '0001047469-15-001106',
#   'fy': 2014,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2015-02-24'},
#  {'end': '2014-12-31',
#   'val': 117532000000,
#   'accn': '0000051143-15-000003',
#   'fy': 2015,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2015-04-28'},
#  {'end': '2014-12-31',
#   'val': 117532000000,
#   'accn': '0000051143-15-000005',
#   'fy': 2015,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2015-07-28'},
#  {'end': '2014-12-31',
#   'val': 117532000000,
#   'accn': '0000051143-15-000009',
#   'fy': 2015,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2015-10-27'},
#  {'end': '2014-12-31',
#   'val': 117271000000,
#   'accn': '0001047469-16-010329',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2016-02-23'},
#  {'end': '2014-12-31',
#   'val': 117271000000,
#   'accn': '0001104659-16-126857',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '8-K',
#   'filed': '2016-06-13'},
#  {'end': '2014-12-31',
#   'val': 117271000000,
#   'accn': '0001047469-17-001061',
#   'fy': 2016,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2017-02-28',
#   'frame': 'CY2014Q4I'},
#  {'end': '2015-03-31',
#   'val': 112037000000,
#   'accn': '0000051143-15-000003',
#   'fy': 2015,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2015-04-28',
#   'frame': 'CY2015Q1I'},
#  {'end': '2015-06-30',
#   'val': 112729000000,
#   'accn': '0000051143-15-000005',
#   'fy': 2015,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2015-07-28',
#   'frame': 'CY2015Q2I'},
#  {'end': '2015-09-30',
#   'val': 108649000000,
#   'accn': '0000051143-15-000009',
#   'fy': 2015,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2015-10-27',
#   'frame': 'CY2015Q3I'},
#  {'end': '2015-12-31',
#   'val': 110495000000,
#   'accn': '0001047469-16-010329',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2016-02-23'},
#  {'end': '2015-12-31',
#   'val': 110495000000,
#   'accn': '0000051143-16-000013',
#   'fy': 2016,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2016-04-26'},
#  {'end': '2015-12-31',
#   'val': 110495000000,
#   'accn': '0001104659-16-126857',
#   'fy': 2015,
#   'fp': 'FY',
#   'form': '8-K',
#   'filed': '2016-06-13'},
#  {'end': '2015-12-31',
#   'val': 110495000000,
#   'accn': '0001104659-16-134367',
#   'fy': 2016,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2016-07-26'},
#  {'end': '2015-12-31',
#   'val': 110495000000,
#   'accn': '0001104659-16-151931',
#   'fy': 2016,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2016-10-25'},
#  {'end': '2015-12-31',
#   'val': 110495000000,
#   'accn': '0001047469-17-001061',
#   'fy': 2016,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2017-02-28'},
#  {'end': '2015-12-31',
#   'val': 110495000000,
#   'accn': '0001047469-18-001117',
#   'fy': 2017,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2018-02-27',
#   'frame': 'CY2015Q4I'},
#  {'end': '2016-03-31',
#   'val': 118856000000,
#   'accn': '0000051143-16-000013',
#   'fy': 2016,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2016-04-26',
#   'frame': 'CY2016Q1I'},
#  {'end': '2016-06-30',
#   'val': 118056000000,
#   'accn': '0001104659-16-134367',
#   'fy': 2016,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2016-07-26',
#   'frame': 'CY2016Q2I'},
#  {'end': '2016-09-30',
#   'val': 115606000000,
#   'accn': '0001104659-16-151931',
#   'fy': 2016,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2016-10-25',
#   'frame': 'CY2016Q3I'},
#  {'end': '2016-12-31',
#   'val': 117470000000,
#   'accn': '0001047469-17-001061',
#   'fy': 2016,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2017-02-28'},
#  {'end': '2016-12-31',
#   'val': 117470000000,
#   'accn': '0001104659-17-025881',
#   'fy': 2017,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2017-04-25'},
#  {'end': '2016-12-31',
#   'val': 117470000000,
#   'accn': '0001104659-17-046808',
#   'fy': 2017,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2017-07-25'},
#  {'end': '2016-12-31',
#   'val': 117470000000,
#   'accn': '0001104659-17-064968',
#   'fy': 2017,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2017-10-31'},
#  {'end': '2016-12-31',
#   'val': 117470000000,
#   'accn': '0001047469-18-001117',
#   'fy': 2017,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2018-02-27'},
#  {'end': '2016-12-31',
#   'val': 117470000000,
#   'accn': '0001047469-19-000712',
#   'fy': 2018,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2019-02-26',
#   'frame': 'CY2016Q4I'},
#  {'end': '2017-03-31',
#   'val': 117495000000,
#   'accn': '0001104659-17-025881',
#   'fy': 2017,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2017-04-25',
#   'frame': 'CY2017Q1I'},
#  {'end': '2017-06-30',
#   'val': 120495000000,
#   'accn': '0001104659-17-046808',
#   'fy': 2017,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2017-07-25',
#   'frame': 'CY2017Q2I'},
#  {'end': '2017-09-30',
#   'val': 121636000000,
#   'accn': '0001104659-17-064968',
#   'fy': 2017,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2017-10-31',
#   'frame': 'CY2017Q3I'},
#  {'end': '2017-12-31',
#   'val': 125356000000,
#   'accn': '0001047469-18-001117',
#   'fy': 2017,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2018-02-27'},
#  {'end': '2017-12-31',
#   'val': 125356000000,
#   'accn': '0001104659-18-026178',
#   'fy': 2018,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2018-04-24'},
#  {'end': '2017-12-31',
#   'val': 125356000000,
#   'accn': '0001104659-18-048404',
#   'fy': 2018,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2018-07-31'},
#  {'end': '2017-12-31',
#   'val': 125356000000,
#   'accn': '0001104659-18-064673',
#   'fy': 2018,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2018-10-30'},
#  {'end': '2017-12-31',
#   'val': 125356000000,
#   'accn': '0001047469-19-000712',
#   'fy': 2018,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2019-02-26'},
#  {'end': '2017-12-31',
#   'val': 125356000000,
#   'accn': '0001558370-20-001334',
#   'fy': 2019,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2020-02-25',
#   'frame': 'CY2017Q4I'},
#  {'end': '2018-03-31',
#   'val': 125285000000,
#   'accn': '0001104659-18-026178',
#   'fy': 2018,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2018-04-24',
#   'frame': 'CY2018Q1I'},
#  {'end': '2018-06-30',
#   'val': 121622000000,
#   'accn': '0001104659-18-048404',
#   'fy': 2018,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2018-07-31',
#   'frame': 'CY2018Q2I'},
#  {'end': '2018-09-30',
#   'val': 121990000000,
#   'accn': '0001104659-18-064673',
#   'fy': 2018,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2018-10-30',
#   'frame': 'CY2018Q3I'},
#  {'end': '2018-12-31',
#   'val': 123382000000,
#   'accn': '0001047469-19-000712',
#   'fy': 2018,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2019-02-26'},
#  {'end': '2018-12-31',
#   'val': 123382000000,
#   'accn': '0001104659-19-025328',
#   'fy': 2019,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2019-04-30'},
#  {'end': '2018-12-31',
#   'val': 123382000000,
#   'accn': '0001558370-19-006560',
#   'fy': 2019,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2019-07-30'},
#  {'end': '2018-12-31',
#   'val': 123382000000,
#   'accn': '0001558370-19-009324',
#   'fy': 2019,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2019-10-30'},
#  {'end': '2018-12-31',
#   'val': 123382000000,
#   'accn': '0001558370-20-001334',
#   'fy': 2019,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2020-02-25'},
#  {'end': '2018-12-31',
#   'val': 123382000000,
#   'accn': '0001558370-21-001489',
#   'fy': 2020,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2021-02-23',
#   'frame': 'CY2018Q4I'},
#  {'end': '2019-03-31',
#   'val': 130926000000,
#   'accn': '0001104659-19-025328',
#   'fy': 2019,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2019-04-30',
#   'frame': 'CY2019Q1I'},
#  {'end': '2019-06-30',
#   'val': 154652000000,
#   'accn': '0001558370-19-006560',
#   'fy': 2019,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2019-07-30',
#   'frame': 'CY2019Q2I'},
#  {'end': '2019-09-30',
#   'val': 149620000000,
#   'accn': '0001558370-19-009324',
#   'fy': 2019,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2019-10-30',
#   'frame': 'CY2019Q3I'},
#  {'end': '2019-12-31',
#   'val': 152186000000,
#   'accn': '0001558370-20-001334',
#   'fy': 2019,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2020-02-25'},
#  {'end': '2019-12-31',
#   'val': 152186000000,
#   'accn': '0001558370-20-004491',
#   'fy': 2020,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2020-04-28'},
#  {'end': '2019-12-31',
#   'val': 152186000000,
#   'accn': '0001558370-20-008516',
#   'fy': 2020,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2020-07-28'},
#  {'end': '2019-12-31',
#   'val': 152186000000,
#   'accn': '0001558370-20-011799',
#   'fy': 2020,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2020-10-27'},
#  {'end': '2019-12-31',
#   'val': 152186000000,
#   'accn': '0001558370-21-001489',
#   'fy': 2020,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2021-02-23'},
#  {'end': '2019-12-31',
#   'val': 152186000000,
#   'accn': '0001558370-22-001584',
#   'fy': 2021,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2022-02-22',
#   'frame': 'CY2019Q4I'},
#  {'end': '2020-03-31',
#   'val': 153403000000,
#   'accn': '0001558370-20-004491',
#   'fy': 2020,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2020-04-28',
#   'frame': 'CY2020Q1I'},
#  {'end': '2020-06-30',
#   'val': 154200000000,
#   'accn': '0001558370-20-008516',
#   'fy': 2020,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2020-07-28',
#   'frame': 'CY2020Q2I'},
#  {'end': '2020-09-30',
#   'val': 154128000000,
#   'accn': '0001558370-20-011799',
#   'fy': 2020,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2020-10-27',
#   'frame': 'CY2020Q3I'},
#  {'end': '2020-12-31',
#   'val': 155971000000,
#   'accn': '0001558370-21-001489',
#   'fy': 2020,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2021-02-23'},
#  {'end': '2020-12-31',
#   'val': 155971000000,
#   'accn': '0001558370-21-004922',
#   'fy': 2021,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2021-04-27'},
#  {'end': '2020-12-31',
#   'val': 155971000000,
#   'accn': '0001558370-21-009351',
#   'fy': 2021,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2021-07-27'},
#  {'end': '2020-12-31',
#   'val': 155971000000,
#   'accn': '0001558370-21-014734',
#   'fy': 2021,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2021-11-05'},
#  {'end': '2020-12-31',
#   'val': 155971000000,
#   'accn': '0001558370-22-001584',
#   'fy': 2021,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2022-02-22',
#   'frame': 'CY2020Q4I'},
#  {'end': '2021-03-31',
#   'val': 148629000000,
#   'accn': '0001558370-21-004922',
#   'fy': 2021,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2021-04-27',
#   'frame': 'CY2021Q1I'},
#  {'end': '2021-06-30',
#   'val': 146814000000,
#   'accn': '0001558370-21-009351',
#   'fy': 2021,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2021-07-27',
#   'frame': 'CY2021Q2I'},
#  {'end': '2021-09-30',
#   'val': 144214000000,
#   'accn': '0001558370-21-014734',
#   'fy': 2021,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2021-11-05',
#   'frame': 'CY2021Q3I'},
#  {'end': '2021-12-31',
#   'val': 132001000000,
#   'accn': '0001558370-22-001584',
#   'fy': 2021,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2022-02-22'},
#  {'end': '2021-12-31',
#   'val': 132001000000,
#   'accn': '0001558370-22-005983',
#   'fy': 2022,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2022-04-26',
#   'frame': 'CY2021Q4I'},
#  {'end': '2022-03-31',
#   'val': 133275000000,
#   'accn': '0001558370-22-005983',
#   'fy': 2022,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2022-04-26',
#   'frame': 'CY2022Q1I'}]

# %%
consolidate(keyQuarters(gaap["Revenues"]["units"]["USD"]))
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_12040\4174423929.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   frame = frame.append(make_q4(frame))
# frame
# CY2007      98786000000.00
# CY2008     103630000000.00
# CY2009      95758000000.00
# CY2008Q2    26820000000.00
# CY2008Q3    25302000000.00
#                  ...
# CY2021Q1    13187000000.00
# CY2021Q2    18745000000.00
# CY2021Q3    17618000000.00
# CY2021Q4     7800000000.00
# CY2022Q1    14197000000.00
# Name: val, Length: 69, dtype: float64

# %%
t["frame2"] = t["frame"].transform(lambda x: x[2:])

# %%
s = pd.DataFrame(consolidate(keyQuarters(gaap["Revenues"]["units"]["USD"])))

# %%
s
# Out:
#                    val
# frame
# CY2007     98786000000
# CY2008Q2   26820000000
# CY2008Q3   25302000000
# CY2008    103630000000
# CY2009Q1   21711000000
# CY2009Q2   23250000000
# CY2009Q3   23566000000
# CY2009     95758000000
# CY2010Q1   22857000000
# CY2010Q2   23724000000
# CY2010Q3   24271000000
# CY2010     99870000000
# CY2011Q1   24607000000
# CY2011Q2   26666000000
# CY2011Q3   26157000000
# CY2011    106916000000
# CY2012Q1   24673000000
# CY2012Q2   25783000000
# CY2012Q3   24747000000
# CY2012    102874000000
# CY2013Q1   23408000000
# CY2013Q2   24924000000
# CY2013Q3   23338000000
# CY2013     98367000000
# CY2014Q1   22236000000
# CY2014Q2   24047000000
# CY2014Q3   22397000000
# CY2014     92793000000
# CY2015Q1   19590000000
# CY2015Q2   20813000000
# CY2015Q3   19280000000
# CY2015     81741000000
# CY2016Q1   18684000000
# CY2016Q2   20238000000
# CY2016Q3   19226000000
# CY2016     79919000000
# CY2017Q1   18155000000
# CY2017Q2   19289000000
# CY2017Q3   19153000000
# CY2017     79139000000
# CY2018Q1   19072000000
# CY2018Q2   20003000000
# CY2018Q3   18756000000
# CY2018     79591000000
# CY2019Q1   18182000000
# CY2019Q2   19161000000
# CY2019Q3   18028000000
# CY2019     57714000000
# CY2020Q1   17571000000
# CY2020Q2   18123000000
# CY2020Q3   17560000000
# CY2020     55179000000
# CY2021Q1   13187000000
# CY2021Q2   18745000000
# CY2021Q3   17618000000
# CY2021     57350000000
# CY2022Q1   14197000000

# %%
make_q4(t)["fy"].transform(lambda x: f"CY{x}Q4")
# Out:
# 0    CY2020Q4
# 1    CY2021Q4
# Name: fy, dtype: object

# %%
chart = make_frame(gaap)

# %%
chart.T.to_excel("example_table.xlsx")

# %%
chart.tail(20).T
# Out:
# frame                                       CY2017Q2       CY2017Q3  \
# Total revenue                         19289000000.00 19153000000.00
# Total cost                            10321000000.00 10172000000.00
# Gross profit                           8968000000.00  8981000000.00
# Selling, general and administrative    5033000000.00  4606000000.00
# Research, development and engineering  1436000000.00  1291000000.00
# Interest expense                        147000000.00   168000000.00
# Income before taxes                    2443000000.00  3065000000.00
# Net income                             2331000000.00  2726000000.00
#
# frame                                       CY2017Q4       CY2018Q1  \
# Total revenue                         22542000000.00 19072000000.00
# Total cost                            11492000000.00 10825000000.00
# Gross profit                          11050000000.00  8247000000.00
# Selling, general and administrative    5014000000.00  5445000000.00
# Research, development and engineering  1379000000.00  1405000000.00
# Interest expense                        165000000.00   165000000.00
# Income before taxes                    4468000000.00  1136000000.00
# Net income                            -1054000000.00  1679000000.00
#
# frame                                       CY2018Q2       CY2018Q3  \
# Total revenue                         20003000000.00 18756000000.00
# Total cost                            10804000000.00  9953000000.00
# Gross profit                           9199000000.00  8803000000.00
# Selling, general and administrative    4857000000.00  4363000000.00
# Research, development and engineering  1364000000.00  1252000000.00
# Interest expense                        173000000.00   191000000.00
# Income before taxes                    2776000000.00  2996000000.00
# Net income                             2404000000.00  2694000000.00
#
# frame                                       CY2018Q4       CY2019Q1  \
# Total revenue                         21760000000.00 18182000000.00
# Total cost                            11073000000.00 10139000000.00
# Gross profit                          10687000000.00  8043000000.00
# Selling, general and administrative    4701000000.00  4691000000.00
# Research, development and engineering  1358000000.00  1433000000.00
# Interest expense                        194000000.00   210000000.00
# Income before taxes                    4434000000.00  1883000000.00
# Net income                             1951000000.00  1591000000.00
#
# frame                                       CY2019Q2       CY2019Q3  \
# Total revenue                         19161000000.00 18028000000.00
# Total cost                            10151000000.00  9692000000.00
# Gross profit                           9010000000.00  8336000000.00
# Selling, general and administrative    5456000000.00  5024000000.00
# Research, development and engineering  1407000000.00  1553000000.00
# Interest expense                        348000000.00   432000000.00
# Income before taxes                    2768000000.00  1522000000.00
# Net income                             2498000000.00  1672000000.00
#
# frame                                       CY2019Q4       CY2020Q1  \
# Total revenue                          2343000000.00 17571000000.00
# Total cost                            -3801000000.00  9649000000.00
# Gross profit                           6144000000.00  7922000000.00
# Selling, general and administrative    3553000000.00  5955000000.00
# Research, development and engineering  1517000000.00  1625000000.00
# Interest expense                        354000000.00   326000000.00
# Income before taxes                    1033000000.00   -49000000.00
# Net income                             3670000000.00  1175000000.00
#
# frame                                       CY2020Q2       CY2020Q3  \
# Total revenue                         18123000000.00 17560000000.00
# Total cost                             9423000000.00  9130000000.00
# Gross profit                           8700000000.00  8430000000.00
# Selling, general and administrative    5248000000.00  4647000000.00
# Research, development and engineering  1582000000.00  1515000000.00
# Interest expense                        323000000.00   323000000.00
# Income before taxes                    1571000000.00  1827000000.00
# Net income                             1361000000.00  1698000000.00
#
# frame                                       CY2020Q4       CY2021Q1  \
# Total revenue                          1925000000.00 13187000000.00
# Total cost                            -3888000000.00  6160000000.00
# Gross profit                           5813000000.00  7027000000.00
# Selling, general and administrative    4711000000.00  4688000000.00
# Research, development and engineering  1540000000.00  1616000000.00
# Interest expense                        316000000.00   280000000.00
# Income before taxes                    -777000000.00   244000000.00
# Net income                             1356000000.00   955000000.00
#
# frame                                       CY2021Q2       CY2021Q3  \
# Total revenue                         18745000000.00 17618000000.00
# Total cost                             9741000000.00  9447000000.00
# Gross profit                           9004000000.00  8171000000.00
# Selling, general and administrative    5334000000.00  4860000000.00
# Research, development and engineering  1657000000.00  1621000000.00
# Interest expense                        281000000.00   291000000.00
# Income before taxes                    1552000000.00  1319000000.00
# Net income                             1325000000.00  1130000000.00
#
# frame                                      CY2021Q4       CY2022Q1
# Total revenue                         7800000000.00 14197000000.00
# Total cost                             517000000.00  6862000000.00
# Gross profit                          7284000000.00  7335000000.00
# Selling, general and administrative   3863000000.00  4597000000.00
# Research, development and engineering 1594000000.00  1679000000.00
# Interest expense                       303000000.00   311000000.00
# Income before taxes                   1722000000.00   623000000.00
# Net income                            2333000000.00   733000000.00

# %%
gaap["NetIncomeLoss"]
# Out:
# {'label': 'Net Income (Loss) Attributable to Parent',
#  'description': 'The portion of profit or loss for the period, net of income taxes, which is attributable to the parent.',
#  'units': {'USD': [{'start': '2015-01-01',
#     'end': '2015-12-31',
#     'val': 13190000000,
#     'accn': '0001047469-18-001117',
#     'fy': 2017,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2018-02-27',
#     'frame': 'CY2015'},
#    {'start': '2016-01-01',
#     'end': '2016-03-31',
#     'val': 2014000000,
#     'accn': '0001104659-17-025881',
#     'fy': 2017,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2017-04-25',
#     'frame': 'CY2016Q1'},
#    {'start': '2016-01-01',
#     'end': '2016-06-30',
#     'val': 4518000000,
#     'accn': '0001104659-17-046808',
#     'fy': 2017,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2017-07-25'},
#    {'start': '2016-04-01',
#     'end': '2016-06-30',
#     'val': 2504000000,
#     'accn': '0001104659-17-046808',
#     'fy': 2017,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2017-07-25',
#     'frame': 'CY2016Q2'},
#    {'start': '2016-01-01',
#     'end': '2016-09-30',
#     'val': 7371000000,
#     'accn': '0001104659-17-064968',
#     'fy': 2017,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2017-10-31'},
#    {'start': '2016-07-01',
#     'end': '2016-09-30',
#     'val': 2853000000,
#     'accn': '0001104659-17-064968',
#     'fy': 2017,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2017-10-31',
#     'frame': 'CY2016Q3'},
#    {'start': '2016-01-01',
#     'end': '2016-12-31',
#     'val': 11872000000,
#     'accn': '0001047469-18-001117',
#     'fy': 2017,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2018-02-27'},
#    {'start': '2016-01-01',
#     'end': '2016-12-31',
#     'val': 11872000000,
#     'accn': '0001047469-19-000712',
#     'fy': 2018,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2019-02-26',
#     'frame': 'CY2016'},
#    {'start': '2017-01-01',
#     'end': '2017-03-31',
#     'val': 1750000000,
#     'accn': '0001104659-17-025881',
#     'fy': 2017,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2017-04-25'},
#    {'start': '2017-01-01',
#     'end': '2017-03-31',
#     'val': 1750000000,
#     'accn': '0001104659-18-026178',
#     'fy': 2018,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2018-04-24',
#     'frame': 'CY2017Q1'},
#    {'start': '2017-01-01',
#     'end': '2017-06-30',
#     'val': 4082000000,
#     'accn': '0001104659-17-046808',
#     'fy': 2017,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2017-07-25'},
#    {'start': '2017-01-01',
#     'end': '2017-06-30',
#     'val': 4082000000,
#     'accn': '0001104659-18-048404',
#     'fy': 2018,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2018-07-31'},
#    {'start': '2017-04-01',
#     'end': '2017-06-30',
#     'val': 2331000000,
#     'accn': '0001104659-17-046808',
#     'fy': 2017,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2017-07-25'},
#    {'start': '2017-04-01',
#     'end': '2017-06-30',
#     'val': 2331000000,
#     'accn': '0001104659-18-048404',
#     'fy': 2018,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2018-07-31',
#     'frame': 'CY2017Q2'},
#    {'start': '2017-01-01',
#     'end': '2017-09-30',
#     'val': 6807000000,
#     'accn': '0001104659-17-064968',
#     'fy': 2017,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2017-10-31'},
#    {'start': '2017-01-01',
#     'end': '2017-09-30',
#     'val': 6807000000,
#     'accn': '0001104659-18-064673',
#     'fy': 2018,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2018-10-30'},
#    {'start': '2017-07-01',
#     'end': '2017-09-30',
#     'val': 2726000000,
#     'accn': '0001104659-17-064968',
#     'fy': 2017,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2017-10-31'},
#    {'start': '2017-07-01',
#     'end': '2017-09-30',
#     'val': 2726000000,
#     'accn': '0001104659-18-064673',
#     'fy': 2018,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2018-10-30',
#     'frame': 'CY2017Q3'},
#    {'start': '2017-01-01',
#     'end': '2017-12-31',
#     'val': 5753000000,
#     'accn': '0001047469-18-001117',
#     'fy': 2017,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2018-02-27'},
#    {'start': '2017-01-01',
#     'end': '2017-12-31',
#     'val': 5753000000,
#     'accn': '0001047469-19-000712',
#     'fy': 2018,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2019-02-26'},
#    {'start': '2017-01-01',
#     'end': '2017-12-31',
#     'val': 5753000000,
#     'accn': '0001558370-20-001334',
#     'fy': 2019,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2020-02-25',
#     'frame': 'CY2017'},
#    {'start': '2018-01-01',
#     'end': '2018-03-31',
#     'val': 1679000000,
#     'accn': '0001104659-18-026178',
#     'fy': 2018,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2018-04-24'},
#    {'start': '2018-01-01',
#     'end': '2018-03-31',
#     'val': 1679000000,
#     'accn': '0001104659-19-025328',
#     'fy': 2019,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2019-04-30',
#     'frame': 'CY2018Q1'},
#    {'start': '2018-01-01',
#     'end': '2018-06-30',
#     'val': 4083000000,
#     'accn': '0001104659-18-048404',
#     'fy': 2018,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2018-07-31'},
#    {'start': '2018-01-01',
#     'end': '2018-06-30',
#     'val': 4083000000,
#     'accn': '0001558370-19-006560',
#     'fy': 2019,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2019-07-30'},
#    {'start': '2018-04-01',
#     'end': '2018-06-30',
#     'val': 2404000000,
#     'accn': '0001104659-18-048404',
#     'fy': 2018,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2018-07-31'},
#    {'start': '2018-04-01',
#     'end': '2018-06-30',
#     'val': 2404000000,
#     'accn': '0001558370-19-006560',
#     'fy': 2019,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2019-07-30',
#     'frame': 'CY2018Q2'},
#    {'start': '2018-01-01',
#     'end': '2018-09-30',
#     'val': 6777000000,
#     'accn': '0001104659-18-064673',
#     'fy': 2018,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2018-10-30'},
#    {'start': '2018-01-01',
#     'end': '2018-09-30',
#     'val': 6777000000,
#     'accn': '0001558370-19-009324',
#     'fy': 2019,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2019-10-30'},
#    {'start': '2018-07-01',
#     'end': '2018-09-30',
#     'val': 2694000000,
#     'accn': '0001104659-18-064673',
#     'fy': 2018,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2018-10-30'},
#    {'start': '2018-07-01',
#     'end': '2018-09-30',
#     'val': 2694000000,
#     'accn': '0001558370-19-009324',
#     'fy': 2019,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2019-10-30',
#     'frame': 'CY2018Q3'},
#    {'start': '2018-01-01',
#     'end': '2018-12-31',
#     'val': 8728000000,
#     'accn': '0001047469-19-000712',
#     'fy': 2018,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2019-02-26'},
#    {'start': '2018-01-01',
#     'end': '2018-12-31',
#     'val': 8728000000,
#     'accn': '0001558370-20-001334',
#     'fy': 2019,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2020-02-25'},
#    {'start': '2018-01-01',
#     'end': '2018-12-31',
#     'val': 8728000000,
#     'accn': '0001558370-21-001489',
#     'fy': 2020,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2021-02-23',
#     'frame': 'CY2018'},
#    {'start': '2019-01-01',
#     'end': '2019-03-31',
#     'val': 1591000000,
#     'accn': '0001104659-19-025328',
#     'fy': 2019,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2019-04-30'},
#    {'start': '2019-01-01',
#     'end': '2019-03-31',
#     'val': 1591000000,
#     'accn': '0001558370-20-004491',
#     'fy': 2020,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2020-04-28',
#     'frame': 'CY2019Q1'},
#    {'start': '2019-01-01',
#     'end': '2019-06-30',
#     'val': 4089000000,
#     'accn': '0001558370-19-006560',
#     'fy': 2019,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2019-07-30'},
#    {'start': '2019-01-01',
#     'end': '2019-06-30',
#     'val': 4089000000,
#     'accn': '0001558370-20-008516',
#     'fy': 2020,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2020-07-28'},
#    {'start': '2019-04-01',
#     'end': '2019-06-30',
#     'val': 2498000000,
#     'accn': '0001558370-19-006560',
#     'fy': 2019,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2019-07-30'},
#    {'start': '2019-04-01',
#     'end': '2019-06-30',
#     'val': 2498000000,
#     'accn': '0001558370-20-008516',
#     'fy': 2020,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2020-07-28',
#     'frame': 'CY2019Q2'},
#    {'start': '2019-01-01',
#     'end': '2019-09-30',
#     'val': 5761000000,
#     'accn': '0001558370-19-009324',
#     'fy': 2019,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2019-10-30'},
#    {'start': '2019-01-01',
#     'end': '2019-09-30',
#     'val': 5761000000,
#     'accn': '0001558370-20-011799',
#     'fy': 2020,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2020-10-27'},
#    {'start': '2019-07-01',
#     'end': '2019-09-30',
#     'val': 1672000000,
#     'accn': '0001558370-19-009324',
#     'fy': 2019,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2019-10-30'},
#    {'start': '2019-07-01',
#     'end': '2019-09-30',
#     'val': 1672000000,
#     'accn': '0001558370-20-011799',
#     'fy': 2020,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2020-10-27',
#     'frame': 'CY2019Q3'},
#    {'start': '2019-01-01',
#     'end': '2019-12-31',
#     'val': 9431000000,
#     'accn': '0001558370-20-001334',
#     'fy': 2019,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2020-02-25'},
#    {'start': '2019-01-01',
#     'end': '2019-12-31',
#     'val': 9431000000,
#     'accn': '0001558370-21-001489',
#     'fy': 2020,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2021-02-23'},
#    {'start': '2019-01-01',
#     'end': '2019-12-31',
#     'val': 9431000000,
#     'accn': '0001558370-22-001584',
#     'fy': 2021,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2022-02-22',
#     'frame': 'CY2019'},
#    {'start': '2020-01-01',
#     'end': '2020-03-31',
#     'val': 1175000000,
#     'accn': '0001558370-20-004491',
#     'fy': 2020,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2020-04-28'},
#    {'start': '2020-01-01',
#     'end': '2020-03-31',
#     'val': 1175000000,
#     'accn': '0001558370-21-004922',
#     'fy': 2021,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2021-04-27',
#     'frame': 'CY2020Q1'},
#    {'start': '2020-01-01',
#     'end': '2020-06-30',
#     'val': 2536000000,
#     'accn': '0001558370-20-008516',
#     'fy': 2020,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2020-07-28'},
#    {'start': '2020-01-01',
#     'end': '2020-06-30',
#     'val': 2536000000,
#     'accn': '0001558370-21-009351',
#     'fy': 2021,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2021-07-27'},
#    {'start': '2020-04-01',
#     'end': '2020-06-30',
#     'val': 1361000000,
#     'accn': '0001558370-20-008516',
#     'fy': 2020,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2020-07-28'},
#    {'start': '2020-04-01',
#     'end': '2020-06-30',
#     'val': 1361000000,
#     'accn': '0001558370-21-009351',
#     'fy': 2021,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2021-07-27',
#     'frame': 'CY2020Q2'},
#    {'start': '2020-01-01',
#     'end': '2020-09-30',
#     'val': 4234000000,
#     'accn': '0001558370-20-011799',
#     'fy': 2020,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2020-10-27'},
#    {'start': '2020-01-01',
#     'end': '2020-09-30',
#     'val': 4234000000,
#     'accn': '0001558370-21-014734',
#     'fy': 2021,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2021-11-05'},
#    {'start': '2020-07-01',
#     'end': '2020-09-30',
#     'val': 1698000000,
#     'accn': '0001558370-20-011799',
#     'fy': 2020,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2020-10-27'},
#    {'start': '2020-07-01',
#     'end': '2020-09-30',
#     'val': 1698000000,
#     'accn': '0001558370-21-014734',
#     'fy': 2021,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2021-11-05',
#     'frame': 'CY2020Q3'},
#    {'start': '2020-01-01',
#     'end': '2020-12-31',
#     'val': 5590000000,
#     'accn': '0001558370-21-001489',
#     'fy': 2020,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2021-02-23'},
#    {'start': '2020-01-01',
#     'end': '2020-12-31',
#     'val': 5590000000,
#     'accn': '0001558370-22-001584',
#     'fy': 2021,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2022-02-22',
#     'frame': 'CY2020'},
#    {'start': '2021-01-01',
#     'end': '2021-03-31',
#     'val': 955000000,
#     'accn': '0001558370-21-004922',
#     'fy': 2021,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2021-04-27'},
#    {'start': '2021-01-01',
#     'end': '2021-03-31',
#     'val': 955000000,
#     'accn': '0001558370-22-005983',
#     'fy': 2022,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2022-04-26',
#     'frame': 'CY2021Q1'},
#    {'start': '2021-01-01',
#     'end': '2021-06-30',
#     'val': 2280000000,
#     'accn': '0001558370-21-009351',
#     'fy': 2021,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2021-07-27'},
#    {'start': '2021-04-01',
#     'end': '2021-06-30',
#     'val': 1325000000,
#     'accn': '0001558370-21-009351',
#     'fy': 2021,
#     'fp': 'Q2',
#     'form': '10-Q',
#     'filed': '2021-07-27',
#     'frame': 'CY2021Q2'},
#    {'start': '2021-01-01',
#     'end': '2021-09-30',
#     'val': 3410000000,
#     'accn': '0001558370-21-014734',
#     'fy': 2021,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2021-11-05'},
#    {'start': '2021-07-01',
#     'end': '2021-09-30',
#     'val': 1130000000,
#     'accn': '0001558370-21-014734',
#     'fy': 2021,
#     'fp': 'Q3',
#     'form': '10-Q',
#     'filed': '2021-11-05',
#     'frame': 'CY2021Q3'},
#    {'start': '2021-01-01',
#     'end': '2021-12-31',
#     'val': 5743000000,
#     'accn': '0001558370-22-001584',
#     'fy': 2021,
#     'fp': 'FY',
#     'form': '10-K',
#     'filed': '2022-02-22',
#     'frame': 'CY2021'},
#    {'start': '2022-01-01',
#     'end': '2022-03-31',
#     'val': 733000000,
#     'accn': '0001558370-22-005983',
#     'fy': 2022,
#     'fp': 'Q1',
#     'form': '10-Q',
#     'filed': '2022-04-26',
#     'frame': 'CY2022Q1'}]}}

# %%
t[(t["end"] < "2021-12-31") & (t["start"] >= "2021-01-01")]["val"].sum()
# Out:
# 49550000000

# %%
consolidate(keyQuarters(gaap["Revenues"]["units"]["USD"]))
# Out:
#                    val
# frame
# CY2007     98786000000
# CY2008Q2   26820000000
# CY2008Q3   25302000000
# CY2008    103630000000
# CY2009Q1   21711000000
# CY2009Q2   23250000000
# CY2009Q3   23566000000
# CY2009     95758000000
# CY2010Q1   22857000000
# CY2010Q2   23724000000
# CY2010Q3   24271000000
# CY2010     99870000000
# CY2011Q1   24607000000
# CY2011Q2   26666000000
# CY2011Q3   26157000000
# CY2011    106916000000
# CY2012Q1   24673000000
# CY2012Q2   25783000000
# CY2012Q3   24747000000
# CY2012    102874000000
# CY2013Q1   23408000000
# CY2013Q2   24924000000
# CY2013Q3   23338000000
# CY2013     98367000000
# CY2014Q1   22236000000
# CY2014Q2   24047000000
# CY2014Q3   22397000000
# CY2014     92793000000
# CY2015Q1   19590000000
# CY2015Q2   20813000000
# CY2015Q3   19280000000
# CY2015     81741000000
# CY2016Q1   18684000000
# CY2016Q2   20238000000
# CY2016Q3   19226000000
# CY2016     79919000000
# CY2017Q1   18155000000
# CY2017Q2   19289000000
# CY2017Q3   19153000000
# CY2017     79139000000
# CY2018Q1   19072000000
# CY2018Q2   20003000000
# CY2018Q3   18756000000
# CY2018     79591000000
# CY2019Q1   18182000000
# CY2019Q2   19161000000
# CY2019Q3   18028000000
# CY2019     57714000000
# CY2020Q1   17571000000
# CY2020Q2   18123000000
# CY2020Q3   17560000000
# CY2020     55179000000
# CY2021Q1   13187000000
# CY2021Q2   18745000000
# CY2021Q3   17618000000
# CY2021     57350000000
# CY2022Q1   14197000000

# %%
keyQuarters(gaap["Revenues"]["units"]["USD"])[-10:]
# Out:
# [{'start': '2019-01-01',
#   'end': '2019-12-31',
#   'val': 57714000000,
#   'accn': '0001558370-22-001584',
#   'fy': 2021,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2022-02-22',
#   'frame': 'CY2019'},
#  {'start': '2020-01-01',
#   'end': '2020-03-31',
#   'val': 17571000000,
#   'accn': '0001558370-21-004922',
#   'fy': 2021,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2021-04-27',
#   'frame': 'CY2020Q1'},
#  {'start': '2020-04-01',
#   'end': '2020-06-30',
#   'val': 18123000000,
#   'accn': '0001558370-21-009351',
#   'fy': 2021,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2021-07-27',
#   'frame': 'CY2020Q2'},
#  {'start': '2020-07-01',
#   'end': '2020-09-30',
#   'val': 17560000000,
#   'accn': '0001558370-21-014734',
#   'fy': 2021,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2021-11-05',
#   'frame': 'CY2020Q3'},
#  {'start': '2020-01-01',
#   'end': '2020-12-31',
#   'val': 55179000000,
#   'accn': '0001558370-22-001584',
#   'fy': 2021,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2022-02-22',
#   'frame': 'CY2020'},
#  {'start': '2021-01-01',
#   'end': '2021-03-31',
#   'val': 13187000000,
#   'accn': '0001558370-22-005983',
#   'fy': 2022,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2022-04-26',
#   'frame': 'CY2021Q1'},
#  {'start': '2021-04-01',
#   'end': '2021-06-30',
#   'val': 18745000000,
#   'accn': '0001558370-21-009351',
#   'fy': 2021,
#   'fp': 'Q2',
#   'form': '10-Q',
#   'filed': '2021-07-27',
#   'frame': 'CY2021Q2'},
#  {'start': '2021-07-01',
#   'end': '2021-09-30',
#   'val': 17618000000,
#   'accn': '0001558370-21-014734',
#   'fy': 2021,
#   'fp': 'Q3',
#   'form': '10-Q',
#   'filed': '2021-11-05',
#   'frame': 'CY2021Q3'},
#  {'start': '2021-01-01',
#   'end': '2021-12-31',
#   'val': 57350000000,
#   'accn': '0001558370-22-001584',
#   'fy': 2021,
#   'fp': 'FY',
#   'form': '10-K',
#   'filed': '2022-02-22',
#   'frame': 'CY2021'},
#  {'start': '2022-01-01',
#   'end': '2022-03-31',
#   'val': 14197000000,
#   'accn': '0001558370-22-005983',
#   'fy': 2022,
#   'fp': 'Q1',
#   'form': '10-Q',
#   'filed': '2022-04-26',
#   'frame': 'CY2022Q1'}]
