# %% [markdown]
# ## Retrieving S&P 500 stats from tradingview

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
import json
from requests_html import HTMLSession
session = HTMLSession()

# %%
link = "https://www.tradingview.com/symbols/SPX/components/"
res = session.get(link)
res
# Out:
# <Response [200]>

# %%
table = res.html.find("table")
df = pd.read_html(table[0].html)[0]
df.head()
# Out:
#                              Ticker      Price Change % 1D Change 1D  \
# 0       AAgilent Technologies, Inc.  156.49USD      −1.06%  −1.68USD
# 1  AALAmerican Airlines Group, Inc.   16.83USD       9.71%   1.49USD
# 2        AAPAdvance Auto Parts Inc.  152.19USD      −0.71%  −1.09USD
# 3                     AAPLApple Inc  133.41USD      −0.06%  −0.08USD
# 4                   ABBVAbbVie Inc.  152.22USD      −3.15%  −4.95USD
#
#   Technical Rating 1D Volume 1D Volume * Price 1D   Market cap P/E(TTM)  \
# 0                 Buy   809.12K          126.619M   46.332BUSD    37.84
# 1          Strong Buy    96.17M            1.619B   10.938BUSD        —
# 2             Neutral  997.494K          151.809M    9.018BUSD    19.71
# 3             Neutral   71.288M            9.511B    2.122TUSD    21.88
# 4                Sell    7.662M            1.166B  269.198BUSD    20.95
#
#    EPS(TTM) Employees                 Sector
# 0   4.20USD     18.1K      Health Technology
# 1  −2.48USD    123.4K         Transportation
# 2   7.83USD       68K           Retail Trade
# 3   6.14USD      164K  Electronic Technology
# 4   7.53USD       50K      Health Technology

# %%
select_columns = ["name","description", "total_liabilities",
                  "type","typespecs","close","currency",
                  "change","change_abs",
                  "Recommend.All","volume","market_cap_basic",
                  "fundamental_currency_code","price_earnings_ttm","earnings_per_share_basic_ttm",
                  "number_of_employees","total_revenue", "gross_profit", "ebitda", "net_income",
                  "total_assets", "total_debt", "total_current_assets",
                  "dividends_paid", "dps_common_stock_prim_issue_fy",
                  "total_shares_outstanding_fundamental", "sector","market"]

data = {"columns":select_columns,
        "ignore_unknown_fields":False,
        "options":{"lang":"en"},
        "range":[0,600],
        "sort":{"sortBy":"name","sortOrder":"asc"},
        "symbols":{"query":{"types":[]},"tickers":[],"groups":[{"type":"index","values":["SP:SPX"]}]},
        "markets":["america","canada"]}

postlink = "https://scanner.tradingview.com/global/scan"

# %%
res = session.post(postlink, data=json.dumps(data))
print(res)
# Out:
# <Response [200]>

# %%
js = json.loads(res.content)["data"]
info = [i["d"] for i in js]
stocks = pd.DataFrame(data=info, columns=select_columns)
stocks.typespecs = stocks.typespecs.apply(lambda x: " ".join(x))
display(stocks.head(3))
# Out:
#   name                    description total_liabilities   type typespecs  \
# 0    A     Agilent Technologies, Inc.              None  stock    common
# 1  AAL  American Airlines Group, Inc.              None  stock    common
# 2  AAP        Advance Auto Parts Inc.              None  stock    common
#
#    close currency  change  change_abs  Recommend.All  ...        ebitda  \
# 0 156.49      USD   -1.06       -1.68           0.42  ... 1899000000.00
# 1  16.83      USD    9.71        1.49           0.60  ... 1758000000.00
# 2 152.19      USD   -0.71       -1.09          -0.09  ... 1012871000.00
#
#       net_income   total_assets     total_debt  total_current_assets  \
# 0  1254000000.00 10532000000.00  2921000000.00         3778000000.00
# 1 -1993000000.00 66652000000.00 44682000000.00        17377000000.00
# 2   616108000.00 12132079000.00  4086856000.00         6162519000.00
#
#    dividends_paid  dps_common_stock_prim_issue_fy  \
# 0   -250000000.00                            0.84
# 1            0.00                            0.00
# 2   -160925000.00                            3.25
#
#    total_shares_outstanding_fundamental             sector   market
# 0                          296072000.00  Health Technology  america
# 1                          649901000.00     Transportation  america
# 2                           59253700.00       Retail Trade  america
#
# [3 rows x 28 columns]

# %%
stocks[stocks.duplicated(subset="description", keep=False)].to_excel("choosing_share_class.xlsx", index=False)
stocks.to_excel("S&P500_Fundementals_Raw.xlsx", index=False)
# Out:
#   name                    description   type typespecs  close currency  \
# 0    A     Agilent Technologies, Inc.  stock    common 156.49      USD
# 1  AAL  American Airlines Group, Inc.  stock    common  16.83      USD
# 2  AAP        Advance Auto Parts Inc.  stock    common 152.19      USD
#
#    change  change_abs  Recommend.All    volume  ...        ebitda  \
# 0   -1.06       -1.68           0.42    809121  ... 1899000000.00
# 1    9.71        1.49           0.60  96357971  ... 1758000000.00
# 2   -0.71       -1.09          -0.09    997531  ... 1012871000.00
#
#       net_income   total_assets     total_debt  total_current_assets  \
# 0  1254000000.00 10532000000.00  2921000000.00         3778000000.00
# 1 -1993000000.00 66652000000.00 44682000000.00        17377000000.00
# 2   616108000.00 12132079000.00  4086856000.00         6162519000.00
#
#    dividends_paid  dps_common_stock_prim_issue_fy  \
# 0   -250000000.00                            0.84
# 1            0.00                            0.00
# 2   -160925000.00                            3.25
#
#    total_shares_outstanding_fundamental             sector   market
# 0                          296072000.00  Health Technology  america
# 1                          649901000.00     Transportation  america
# 2                           59253700.00       Retail Trade  america
#
# [3 rows x 27 columns]

# %% [markdown]
# ## Quick Data Cleaning

# %%
df = pd.read_excel("S&P500_Fundementals_Raw.xlsx")

# Removing duplicate entries of companies with multiple share classes, and the s&p 500 index itself
df = df.drop_duplicates(subset="description").drop(df[df.name == "SPY"].index[0])

# Removing Columns not relevant to descriptive stats
df = df.drop(["change", "change_abs", "market", "currency", "fundamental_currency_code", "typespecs"], axis=1)
# Renaming Columns for house keeping
df = df.rename(columns={"Recommend.All": "rating", "market_cap_basic": "market_cap", "price_earnings_ttm": "pe_ttm", "earnings_per_share_basic_ttm": "eps_ttm", "dps_common_stock_prim_issue_fy": "dividend_ttm", "total_shares_outstanding_fundamental":"shares_outstanding"})

df.to_excel("S&P500_Fundementals.xlsx", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 503
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  500 non-null    object
#  1   description           500 non-null    object
#  2   type                  500 non-null    object
#  3   close                 500 non-null    float64
#  4   rating                500 non-null    float64
#  5   volume                500 non-null    int64
#  6   market_cap            499 non-null    float64
#  7   pe_ttm                468 non-null    float64
#  8   eps_ttm               498 non-null    float64
#  9   number_of_employees   494 non-null    float64
#  10  total_revenue         499 non-null    float64
#  11  gross_profit          446 non-null    float64
#  12  ebitda                449 non-null    float64
#  13  net_income            499 non-null    float64
#  14  total_assets          499 non-null    float64
#  15  total_debt            499 non-null    float64
#  16  total_current_assets  450 non-null    float64
#  17  dividends_paid        496 non-null    float64
#  18  dividend_ttm          496 non-null    float64
#  19  shares_outstanding    499 non-null    float64
#  20  sector                500 non-null    object
# dtypes: float64(16), int64(1), object(4)
# memory usage: 85.9+ KB
